# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("..\Data\Raw\ACS\ACSDP052018.csv", skiprows=1)
df["year"] = 2018
df.head(5)
# Out:
#   Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.4
# 1                                                0.1
# 2                                                0.2
# 3                                                1.3
# 4                                                0.5
#
#   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#   Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                1.2
# 1                                                0.3
# ...

# %%
list(df.columns)
# Out:
# ['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Margin of Error!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Percent Margin of Error!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Margin of Error!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Percent Margin of Error!!RACE!!Total population!!One race',
#  'Estimate!!RACE!!Total population!!Two or more races',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='Margin of Error')))]
df.head(5)
# Out:
#   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#   Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!RACE!!Total population  Percent Estimate!!RACE!!Total population  \
# 0                             55200                                     55200
# ...

# %%
list(df.columns)
# Out:
# ['Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Estimate!!RACE!!Total population!!Two or more races',
#  'Percent Estimate!!RACE!!Total population!!Two or more races',
#  'Estimate!!RACE!!Total population!!One race.1',
#  'Percent Estimate!!RACE!!Total population!!One race.1',
#  'Estimate!!RACE!!Total population!!One race!!White',
#  'Percent Estimate!!RACE!!Total population!!One race!!White',
#  'Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Percent Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native',
# ...

# %%
df = df.rename(columns = {'Estimate!!SEX AND AGE!!Median age (years)' : 'median_age'})

# %%
# total_pop_col = df[["Estimate!!SEX AND AGE!!Total population", "id"]]
# df = pd.merge(df, total_pop_col, how="left", on="id")
# df.head(5)

# %%
df.columns = df.columns.str.replace('Estimate!!SEX AND AGE!!Total population_y', 'total_pop')
df.head(5)
# Out:
#   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#   Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!RACE!!Total population  Percent Estimate!!RACE!!Total population  \
# 0                             55200                                     55200
# ...

# %%
list(df.columns)
# Out:
# ['Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Estimate!!RACE!!Total population!!Two or more races',
#  'Percent Estimate!!RACE!!Total population!!Two or more races',
#  'Estimate!!RACE!!Total population!!One race.1',
#  'Percent Estimate!!RACE!!Total population!!One race.1',
#  'Estimate!!RACE!!Total population!!One race!!White',
#  'Percent Estimate!!RACE!!Total population!!One race!!White',
#  'Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Percent Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native',
# ...

# %%
df = df[["year", "id", "Estimate!!SEX AND AGE!!Total population",  'Percent Estimate!!SEX AND AGE!!Total population!!Female', "Percent Estimate!!RACE!!Total population!!One race!!White", 'Percent Estimate!!RACE!!Total population!!One race!!Black or African American', 'Percent Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native',  'Percent Estimate!!RACE!!Total population!!One race!!Asian', 'Percent Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander', 'Percent Estimate!!RACE!!Total population!!Two or more races',  'Percent Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)']]
df.head()
# Out:
#    year              id  Estimate!!SEX AND AGE!!Total population  \
# 0  2018  0500000US01001                                    55200
# 1  2018  0500000US01003                                   208107
# 2  2018  0500000US01005                                    25782
# 3  2018  0500000US01007                                    22527
# 4  2018  0500000US01009                                    57645
#
#    Percent Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                               51.3
# 1                                               51.4
# 2                                               46.9
# 3                                               46.1
# 4                                               50.7
#
#    Percent Estimate!!RACE!!Total population!!One race!!White  \
# 0                                               76.9
# 1                                               86.3
# 2                                               47.4
# ...

# %%
df['fips'] = df['id'].str[-5:]
df.head(5)
# Out:
#    year              id  Estimate!!SEX AND AGE!!Total population  \
# 0  2018  0500000US01001                                    55200
# 1  2018  0500000US01003                                   208107
# 2  2018  0500000US01005                                    25782
# 3  2018  0500000US01007                                    22527
# 4  2018  0500000US01009                                    57645
#
#    Percent Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                               51.3
# 1                                               51.4
# 2                                               46.9
# 3                                               46.1
# 4                                               50.7
#
#    Percent Estimate!!RACE!!Total population!!One race!!White  \
# 0                                               76.9
# 1                                               86.3
# 2                                               47.4
# ...

# %%
df = df.drop(columns = ["id"])
df.head()
# Out:
#    year  Estimate!!SEX AND AGE!!Total population  \
# 0  2018                                    55200
# 1  2018                                   208107
# 2  2018                                    25782
# 3  2018                                    22527
# 4  2018                                    57645
#
#    Percent Estimate!!SEX AND AGE!!Total population!!Female  \
# 0                                               51.3
# 1                                               51.4
# 2                                               46.9
# 3                                               46.1
# 4                                               50.7
#
#    Percent Estimate!!RACE!!Total population!!One race!!White  \
# 0                                               76.9
# 1                                               86.3
# 2                                               47.4
# 3                                               76.7
# 4                                               95.5
#
# ...

# %%
df = df.rename(columns={'Estimate!!SEX AND AGE!!Total population':'total_pop', 'Percent Estimate!!SEX AND AGE!!Total population!!Female':'pct_female', 'Percent Estimate!!RACE!!Total population!!One race!!White':'pct_white', "Percent Estimate!!RACE!!Total population!!One race!!Black or African American":"pct_black", "Percent Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native":"pct_native_american", "Percent Estimate!!RACE!!Total population!!One race!!Asian":"pct_asian", "Percent Estimate!!RACE!!Total population!!One race!!Native Hawaiian and Other Pacific Islander":"pct_native_hawaiian_pacific_islander", "Percent Estimate!!RACE!!Total population!!Two or more races":"pct_two_or_more_races", "Percent Estimate!!HISPANIC OR LATINO AND RACE!!Total population!!Hispanic or Latino (of any race)":"pct_hispanic"})
df.head()
# Out:
#    year  total_pop  pct_female  pct_white  pct_black  pct_native_american  \
# 0  2018      55200        51.3       76.9       19.1                  0.3
# 1  2018     208107        51.4       86.3        9.5                  0.7
# 2  2018      25782        46.9       47.4       47.6                  0.3
# 3  2018      22527        46.1       76.7       22.3                  0.0
# 4  2018      57645        50.7       95.5        1.5                  0.2
#
#    pct_asian  pct_native_hawaiian_pacific_islander  pct_two_or_more_races  \
# 0        1.0                                   0.1                    1.9
# 1        0.8                                   0.0                    1.7
# 2        0.4                                   0.0                    1.4
# 3        0.2                                   0.0                    0.8
# 4        0.3                                   0.0                    1.6
#
#    pct_hispanic   fips
# 0           2.8  01001
# 1           4.5  01003
# ...

# %%
df['pct_female'] = df['pct_female'].apply(lambda x: x*0.01)
df['pct_white'] = df['pct_white'].apply(lambda x: x*0.01)
df['pct_black'] = df['pct_black'].apply(lambda x: x*0.01)
df['pct_native_american'] = df['pct_native_american'].apply(lambda x: x*0.01)
df['pct_asian'] = df['pct_asian'].apply(lambda x: x*0.01)
df['pct_native_hawaiian_pacific_islander'] = df['pct_native_hawaiian_pacific_islander'].apply(lambda x: x*0.01)
df['pct_two_or_more_races'] = df['pct_two_or_more_races'].apply(lambda x: x*0.01)
df['pct_hispanic'] = df['pct_hispanic'].apply(lambda x: x*0.01)

df.head()
# Out:
#    year  total_pop  pct_female  pct_white  pct_black  pct_native_american  \
# 0  2018      55200       0.513      0.769      0.191                0.003
# 1  2018     208107       0.514      0.863      0.095                0.007
# 2  2018      25782       0.469      0.474      0.476                0.003
# 3  2018      22527       0.461      0.767      0.223                0.000
# 4  2018      57645       0.507      0.955      0.015                0.002
#
#    pct_asian  pct_native_hawaiian_pacific_islander  pct_two_or_more_races  \
# 0      0.010                                 0.001                  0.019
# 1      0.008                                 0.000                  0.017
# 2      0.004                                 0.000                  0.014
# 3      0.002                                 0.000                  0.008
# 4      0.003                                 0.000                  0.016
#
#    pct_hispanic   fips
# 0         0.028  01001
# 1         0.045  01003
# ...

# %%
df.to_csv("..\Data\Clean\ACS\ACSDP052018_clean.csv")
