# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data/Final/model_pred_values.csv")
df = df.drop(columns = "Unnamed: 0")
df.head()
# Out:
#     fips  act_values_chlamydia  pred_values_chlamydia  errors_chlamydia  \
# 0  45001                 125.0             162.438055        -37.438055
# 1  22001                 345.0             326.619572         18.380428
# 2  51001                 232.0             236.317930         -4.317930
# 3  16001                2203.0            2325.000625       -122.000625
# 4  19001                  27.0              26.857423          0.142577
#
#    act_values_gonorrhea  pred_values_gonorrhea  errors_gonorrhea  \
# 0                  58.0              68.098504        -10.098504
# 1                 112.0             111.336816          0.663184
# 2                  44.0              65.496986        -21.496986
# 3                 580.0             634.838528        -54.838528
# 4                   0.0               9.766284         -9.766284
#
#    act_values_early_non-primary_non-secondary_syphilis  \
# 0                                                1.0
# ...

# %%
print("Number of missing Chlamydia cases:" + str(df["errors_chlamydia"].sum(axis=0)))
print("Number of missing Gonorrhea cases:" + str(df["errors_gonorrhea"].sum(axis=0)))
print("Number of missing Syphilis cases:" + str((df["errors_early_non-primary_non-secondary_syphilis"].sum(axis=0) + df["errors_early_primary_and_secondary_syphilis"].sum(axis=0))))
# Out:
# Number of missing Chlamydia cases:-69132.49772646572
# Number of missing Gonorrhea cases:-41118.55506494062
# Number of missing Syphilis cases:-8541.264528791686
