# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from scipy import signal

# %%
df = pd.read_csv("../Data/Final/STI0220_cov20_pop0220.csv", index_col = 0)
df.head()
# Out:
#    year   fips  cases_chlamydia  \
# 0  2000  45001             61.0
# 1  2000  22001              0.0
# 2  2000  51001            153.0
# 3  2000  16001            644.0
# 4  2000  19001              8.0
#
#    cases_early_non-primary_non-secondary_syphilis  cases_gonorrhea  \
# 0                                             1.0             57.0
# 1                                             8.0              0.0
# 2                                             2.0             88.0
# 3                                             0.0             33.0
# 4                                             0.0              0.0
#
#    cases_primary_and_secondary_syphilis  rate_per_100000_chlamydia  \
# 0                                   2.0                      232.6
# 1                                  11.0                        0.0
# 2                                   0.0                      398.7
# 3                                   1.0                      212.3
# 4                                   0.0                       97.6
#
#    rate_per_100000_early_non-primary_non-secondary_syphilis  \
# 0                                                3.8
# 1                                               13.6
# 2                                                5.2
# 3                                                0.0
# 4                                                0.0
#
#    rate_per_100000_gonorrhea  rate_per_100000_primary_and_secondary_syphilis  \
# 0                      217.4                                             7.6
# 1                        0.0                                            18.7
# 2                      229.3                                             0.0
# 3                       10.9                                             0.3
# 4                        0.0                                             0.0
#
#    ...  pct_ind_transportation_and_warehousing_and_utilities  \
# 0  ...                                                NaN
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
#
#    pct_ind_information  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
#
#    pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_ind_educational_services_and_health_care_and_social_assistance  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_ind_other_services_except_public_administration  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_ind_public_administration  health_insurance_rate  poverty_rate
# 0                            NaN                    NaN           NaN
# 1                            NaN                    NaN           NaN
# 2                            NaN                    NaN           NaN
# 3                            NaN                    NaN           NaN
# 4                            NaN                    NaN           NaN
#
# [5 rows x 180 columns]

# %%
cols = ['cases_gonorrhea','cases_chlamydia','cases_early_non-primary_non-secondary_syphilis',
        'cases_primary_and_secondary_syphilis', 'year']

df = df[df['year'] >= 2002]
fips = df['fips'].unique()
print(len(fips))
print(df.dtypes)
# Out:
# 3214
# year                                                                               int64
# fips                                                                               int64
# cases_chlamydia                                                                  float64
# cases_early_non-primary_non-secondary_syphilis                                   float64
# cases_gonorrhea                                                                  float64
#                                                                                   ...
# pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services    float64
# pct_ind_other_services_except_public_administration                              float64
# pct_ind_public_administration                                                    float64
# health_insurance_rate                                                            float64
# poverty_rate                                                                     float64
# Length: 180, dtype: object

# %%
act_values = []
pred_values = []
errors = []

#fips = fips[:500]

for index, i in enumerate(fips):
    df1 = df[(df['fips']==i) & (df['year']>= 2002)].loc[:,cols]
    df_sum = df1.groupby('year').sum().reset_index()
    df_model = df_sum[["year", "cases_chlamydia"]]
    #print(df_model.shape)
    df_model = df_model[(df_model["year"] <= 2019)]
    df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
    actual_value = df_model.iloc[-1, df_model.columns.get_loc('cases_chlamydia')] 
    df_plot = df_model
    #print(df_model.head(20))
    #print(actual_value)
    
    model = ARIMA(df_model["cases_chlamydia"], order=(2,2,0))
    model_fit = model.fit()
    
    pred = model_fit.predict(18).to_frame()
    fitted_value = pred.iloc[0][0]
    #print(df['year'].nunique())
    
    act_values.append(actual_value)
    pred_values.append(fitted_value)
    errors.append(actual_value - fitted_value)
    
    #print(model_fit.summary())
    if index <= 10:
        print(i , ':    ', actual_value, ' & ', fitted_value)
    #print(i , ':    ', fitted_value)
    #print(df_plot.head(20))
    #print(df_model.head(20))
# Out:
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# 45001 :     -31.647368421052562  &  12.513082338374218
# 22001 :     -4.831578947368371  &  -46.83850490931774
# 51001 :     -41.489473684210395  &  -16.695686597696408
# 16001 :     -36.89999999999873  &  118.02080401658202
# 19001 :     4.273684210526326  &  6.7658116451593155
# 21001 :     -17.99473684210524  &  -2.298887176213344
# 29001 :     -18.942105263157828  &  -5.032931427098916
# 40001 :     -30.06842105263155  &  -9.803608900031612
# 8001 :     -189.6210526315772  &  232.88448110467903
# 19003 :     -3.6315789473684177  &  -1.8670733618148816
# 16003 :     0.08947368421052904  &  -0.4409716093443725
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /Users/dawsonkinsman/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /Users/dawsonkinsman/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /Users/dawsonkinsman/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_5796/2214184100.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [119], in <cell line: 7>()
#      10 df_model = df_sum[["year", "cases_chlamydia"]]
#      11 #print(df_model.shape)
#      12 #df_model = df_model[(df_model["year"] <= 2019)]
# ---> 13 df_model['cases_chlamydia'] = signal.detrend(df_model.cases_chlamydia)
#      14 actual_value = df_model.iloc[-1, df_model.columns.get_loc('cases_chlamydia')]
#      15 df_plot = df_model
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3845, in DataFrame._set_item(self, key, value)
#    3842         if isinstance(existing_piece, DataFrame):
#    3843             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 3845 self._set_item_mgr(key, value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3810, in DataFrame._set_item_mgr(self, key, value)
#    3806 # check if we are modifying a copy
#    3807 # try to set first as we want an invalid
#    3808 # value exception to occur first
#    3809 if len(self):
# -> 3810     self._check_setitem_copy()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4018, in NDFrame._check_setitem_copy(self, t, force)
#    4016     raise com.SettingWithCopyError(t)
#    4017 elif value == "warn":
# -> 4018     warnings.warn(t, com.SettingWithCopyWarning, stacklevel=find_stack_level())
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_exceptions.py:32, in find_stack_level()
#      27 def find_stack_level() -> int:
#      28     """
#      29     Find the first place in the stack that is not inside pandas
#      30     (tests notwithstanding).
#      31     """
# ---> 32     stack = inspect.stack()
#      34     import pandas as pd
#      36     pkg_dir = os.path.dirname(pd.__file__)
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:1554, in stack(context)
#    1552 def stack(context=1):
#    1553     """Return a list of records for the stack above the caller's frame."""
# -> 1554     return getouterframes(sys._getframe(1), context)
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:1531, in getouterframes(frame, context)
#    1529 framelist = []
#    1530 while frame:
# -> 1531     frameinfo = (frame,) + getframeinfo(frame, context)
#    1532     framelist.append(FrameInfo(*frameinfo))
#    1533     frame = frame.f_back
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:1505, in getframeinfo(frame, context)
#    1503 start = lineno - 1 - context//2
#    1504 try:
# -> 1505     lines, lnum = findsource(frame)
#    1506 except OSError:
#    1507     lines = index = None
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:817, in findsource(object)
#     809 def findsource(object):
#     810     """Return the entire source file and starting line number for an object.
#     811
#     812     The argument may be a module, class, method, function, traceback, frame,
#     813     or code object.  The source code is returned as a list of all the lines
#     814     in the file and the line number indexes a line in that list.  An OSError
#     815     is raised if the source code cannot be retrieved."""
# --> 817     file = getsourcefile(object)
#     818     if file:
#     819         # Invalidate cache if needed.
#     820         linecache.checkcache(file)
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:709, in getsourcefile(object)
#     707     return filename
#     708 # only return a non-existent filename if the module has a PEP 302 loader
# --> 709 if getattr(getmodule(object, filename), '__loader__', None) is not None:
#     710     return filename
#     711 # or it is in the linecache
#
# File ~/opt/anaconda3/lib/python3.9/inspect.py:748, in getmodule(object, _filename)
#     746 if ismodule(module) and hasattr(module, '__file__'):
#     747     f = module.__file__
# --> 748     if f == _filesbymodname.get(modname, None):
#     749         # Have already mapped this module, so skip it
#     750         continue
#     751     _filesbymodname[modname] = f
#
# KeyboardInterrupt:

# %%
dff = pd.DataFrame()
dff['fips'] = fips
dff['act_values_chlamydia'] = act_values
dff['pred_values_chlamydia'] = pred_values
dff['errors_chlamydia'] = errors

# %%
act_values = []
pred_values = []
errors = []

#fips = fips[:500]

for index, i in enumerate(fips):
    df1 = df[(df['fips']==i) & (df['year']>= 2002)].loc[:,cols]
    df_sum = df1.groupby('year').sum().reset_index()
    df_model = df_sum[["year", "cases_gonorrhea"]]
    #print(df_model.shape)
    df_model = df_model[(df_model["year"] <= 2019)]
    actual_value = df_model.iloc[-1, df_model.columns.get_loc('cases_gonorrhea')] 
    df_plot = df_model
    #print(df_model.head(20))
    #print(actual_value)
    
    model = ARIMA(df_model["cases_gonorrhea"], order=(2,2,0))
    model_fit = model.fit()
    
    pred = model_fit.predict(18).to_frame()
    fitted_value = pred.iloc[0][0]
    #print(df['year'].nunique())
    
    act_values.append(actual_value)
    pred_values.append(fitted_value)
    errors.append(actual_value - fitted_value)
    
    #print(model_fit.summary())
    if index <= 10:
        print(i , ':    ', actual_value, ' & ', fitted_value)

# %%
print(dff.head(10))
dff.to_csv('../Data/Final/model_pred_values.csv')
