# %%
import pandas as pd
import numpy as np
import os
from functools import reduce

# %%
total = []
folder = '../Data/Clean'

for dirs in os.listdir(folder):
    if not dirs.endswith(('.txt', 'checkpoints', 'HPS', 'ACS', 'USAFacts', 'graphics', 'ility')):
        #print(dirs)
        for files in os.listdir(os.path.join(folder,dirs)):
            if not files.endswith(('.txt', 'checkpoints', 'STD2019_2020_clean.csv')):
                total.append(pd.read_csv(os.path.join(folder,(os.path.join(dirs,files))), sep = ',', index_col = 0))
                print(os.path.join(folder, os.path.join(dirs, files)))
    
folder2 = '../Data/Intermediate'
for files2 in os.listdir(folder2):
    if not (files2.endswith(('.txt', 'checkpoints', 'hps_processed.csv'))):
            total.append(pd.read_csv(os.path.join(folder2,files2), sep = ',', index_col = 0))
            print(files2)
            print(pd.DataFrame(pd.read_csv(os.path.join(folder2,files2), sep = ',', index_col = 0)).shape)
# Out:
# ../Data/Clean/CDC/disagRaceSexHIV2017_2020_clean.csv
# ../Data/Clean/CDC/CDCSTDagesex20192020_clean.csv
# ../Data/Clean/CDC/HIVcountyage_clean.csv
# ../Data/Clean/CDC/HIV_Diagnoses_Prevalence_2008-2021_clean.csv
# CDCSTDoverall2000_2020_processed.csv
# (67586, 130)
# COVIDcounty_cases_processed.csv
# (9426, 4)
# ACSDP03_merge.csv
# (35425, 31)
# ACSDP05_merge.csv
# (35425, 42)
# df00-10.csv
# (27342, 14)

# %%
for index, i in enumerate(total):
    if 'year' in i.columns:
        if 'geography' in i.columns:
            i.drop(columns = 'geography', inplace = True)
        i = i[i['year'] >= 2002]
        #print(i['fips'].dtypes)
        print(list(i.columns))
#list(total[4].columns)
# Out:
# ['year', 'fips', 'cases_female_hiv_diagnoses', 'cases_female_hiv_prevalence', 'cases_female_hiv_viral_suppression', 'cases_female_linkage_to_hiv_care', 'cases_female_prep_coverage_and_number_of_persons_prescribed', 'cases_female_receipt_of_hiv_medical_care', 'cases_male_hiv_diagnoses', 'cases_male_hiv_prevalence', 'cases_male_hiv_viral_suppression', 'cases_male_linkage_to_hiv_care', 'cases_male_prep_coverage_and_number_of_persons_prescribed', 'cases_male_receipt_of_hiv_medical_care', 'percent_female_hiv_viral_suppression', 'percent_female_linkage_to_hiv_care', 'percent_female_prep_coverage_and_number_of_persons_prescribed', 'percent_female_receipt_of_hiv_medical_care', 'percent_male_hiv_viral_suppression', 'percent_male_linkage_to_hiv_care', 'percent_male_prep_coverage_and_number_of_persons_prescribed', 'percent_male_receipt_of_hiv_medical_care', 'rate_per_100000_female_hiv_diagnoses', 'rate_per_100000_female_hiv_prevalence', 'rate_per_100000_male_hiv_diagnoses', 'rate_per_100000_male_hiv_prevalence']
# ['year', 'fips', 'cases_female_chlamydia_0_14', 'cases_female_chlamydia_15_19', 'cases_female_chlamydia_20_24', 'cases_female_chlamydia_25_29', 'cases_female_chlamydia_30_34', 'cases_female_chlamydia_35_39', 'cases_female_chlamydia_40_44', 'cases_female_chlamydia_45_54', 'cases_female_chlamydia_55_64', 'cases_female_chlamydia_65+', 'cases_female_chlamydia_unknown', 'cases_female_early non_primary, non_secondary syphilis_0_14', 'cases_female_early non_primary, non_secondary syphilis_15_19', 'cases_female_early non_primary, non_secondary syphilis_20_24', 'cases_female_early non_primary, non_secondary syphilis_25_29', 'cases_female_early non_primary, non_secondary syphilis_30_34', 'cases_female_early non_primary, non_secondary syphilis_35_39', 'cases_female_early non_primary, non_secondary syphilis_40_44', 'cases_female_early non_primary, non_secondary syphilis_45_54', 'cases_female_early non_primary, non_secondary syphilis_55_64', 'cases_female_early non_primary, non_secondary syphilis_65+', 'cases_female_early non_primary, non_secondary syphilis_unknown', 'cases_female_gonorrhea_0_14', 'cases_female_gonorrhea_15_19', 'cases_female_gonorrhea_20_24', 'cases_female_gonorrhea_25_29', 'cases_female_gonorrhea_30_34', 'cases_female_gonorrhea_35_39', 'cases_female_gonorrhea_40_44', 'cases_female_gonorrhea_45_54', 'cases_female_gonorrhea_55_64', 'cases_female_gonorrhea_65+', 'cases_female_gonorrhea_unknown', 'cases_female_primary and secondary syphilis_0_14', 'cases_female_primary and secondary syphilis_15_19', 'cases_female_primary and secondary syphilis_20_24', 'cases_female_primary and secondary syphilis_25_29', 'cases_female_primary and secondary syphilis_30_34', 'cases_female_primary and secondary syphilis_35_39', 'cases_female_primary and secondary syphilis_40_44', 'cases_female_primary and secondary syphilis_45_54', 'cases_female_primary and secondary syphilis_55_64', 'cases_female_primary and secondary syphilis_65+', 'cases_female_primary and secondary syphilis_unknown', 'cases_male_chlamydia_0_14', 'cases_male_chlamydia_15_19', 'cases_male_chlamydia_20_24', 'cases_male_chlamydia_25_29', 'cases_male_chlamydia_30_34', 'cases_male_chlamydia_35_39', 'cases_male_chlamydia_40_44', 'cases_male_chlamydia_45_54', 'cases_male_chlamydia_55_64', 'cases_male_chlamydia_65+', 'cases_male_chlamydia_unknown', 'cases_male_early non_primary, non_secondary syphilis_0_14', 'cases_male_early non_primary, non_secondary syphilis_15_19', 'cases_male_early non_primary, non_secondary syphilis_20_24', 'cases_male_early non_primary, non_secondary syphilis_25_29', 'cases_male_early non_primary, non_secondary syphilis_30_34', 'cases_male_early non_primary, non_secondary syphilis_35_39', 'cases_male_early non_primary, non_secondary syphilis_40_44', 'cases_male_early non_primary, non_secondary syphilis_45_54', 'cases_male_early non_primary, non_secondary syphilis_55_64', 'cases_male_early non_primary, non_secondary syphilis_65+', 'cases_male_early non_primary, non_secondary syphilis_unknown', 'cases_male_gonorrhea_0_14', 'cases_male_gonorrhea_15_19', 'cases_male_gonorrhea_20_24', 'cases_male_gonorrhea_25_29', 'cases_male_gonorrhea_30_34', 'cases_male_gonorrhea_35_39', 'cases_male_gonorrhea_40_44', 'cases_male_gonorrhea_45_54', 'cases_male_gonorrhea_55_64', 'cases_male_gonorrhea_65+', 'cases_male_gonorrhea_unknown', 'cases_male_primary and secondary syphilis_0_14', 'cases_male_primary and secondary syphilis_15_19', 'cases_male_primary and secondary syphilis_20_24', 'cases_male_primary and secondary syphilis_25_29', 'cases_male_primary and secondary syphilis_30_34', 'cases_male_primary and secondary syphilis_35_39', 'cases_male_primary and secondary syphilis_40_44', 'cases_male_primary and secondary syphilis_45_54', 'cases_male_primary and secondary syphilis_55_64', 'cases_male_primary and secondary syphilis_65+', 'cases_male_primary and secondary syphilis_unknown', 'rateper100000_female_chlamydia_0_14', 'rateper100000_female_chlamydia_15_19', 'rateper100000_fem ...
# ['year', 'fips', 'cases_13-24_HIV diagnoses', 'cases_13-24_HIV prevalence', 'cases_13-24_HIV viral suppression', 'cases_13-24_Linkage to HIV care', 'cases_13-24_PrEP coverage and number of persons prescribed', 'cases_13-24_Receipt of HIV medical care', 'cases_25-34_HIV diagnoses', 'cases_25-34_HIV prevalence', 'cases_25-34_HIV viral suppression', 'cases_25-34_Linkage to HIV care', 'cases_25-34_PrEP coverage and number of persons prescribed', 'cases_25-34_Receipt of HIV medical care', 'cases_35-44_HIV diagnoses', 'cases_35-44_HIV prevalence', 'cases_35-44_HIV viral suppression', 'cases_35-44_Linkage to HIV care', 'cases_35-44_PrEP coverage and number of persons prescribed', 'cases_35-44_Receipt of HIV medical care', 'cases_45-54_HIV diagnoses', 'cases_45-54_HIV prevalence', 'cases_45-54_HIV viral suppression', 'cases_45-54_Linkage to HIV care', 'cases_45-54_PrEP coverage and number of persons prescribed', 'cases_45-54_Receipt of HIV medical care', 'cases_55+_HIV diagnoses', 'cases_55+_HIV prevalence', 'cases_55+_HIV viral suppression', 'cases_55+_Linkage to HIV care', 'cases_55+_PrEP coverage and number of persons prescribed', 'cases_55+_Receipt of HIV medical care', 'percent_13-24_HIV viral suppression', 'percent_13-24_Linkage to HIV care', 'percent_13-24_PrEP coverage and number of persons prescribed', 'percent_13-24_Receipt of HIV medical care', 'percent_25-34_HIV viral suppression', 'percent_25-34_Linkage to HIV care', 'percent_25-34_PrEP coverage and number of persons prescribed', 'percent_25-34_Receipt of HIV medical care', 'percent_35-44_HIV viral suppression', 'percent_35-44_Linkage to HIV care', 'percent_35-44_PrEP coverage and number of persons prescribed', 'percent_35-44_Receipt of HIV medical care', 'percent_45-54_HIV viral suppression', 'percent_45-54_Linkage to HIV care', 'percent_45-54_PrEP coverage and number of persons prescribed', 'percent_45-54_Receipt of HIV medical care', 'percent_55+_HIV viral suppression', 'percent_55+_Linkage to HIV care', 'percent_55+_PrEP coverage and number of persons prescribed', 'percent_55+_Receipt of HIV medical care', 'ratePer100000_13-24_HIV diagnoses', 'ratePer100000_13-24_HIV prevalence', 'ratePer100000_25-34_HIV diagnoses', 'ratePer100000_25-34_HIV prevalence', 'ratePer100000_35-44_HIV diagnoses', 'ratePer100000_35-44_HIV prevalence', 'ratePer100000_45-54_HIV diagnoses', 'ratePer100000_45-54_HIV prevalence', 'ratePer100000_55+_HIV diagnoses', 'ratePer100000_55+_HIV prevalence']
# ['year', 'fips', 'cases_HIV diagnoses', 'cases_HIV prevalence', 'ratePer100000_HIV diagnoses', 'ratePer100000_HIV prevalence']
# ['year', 'fips', 'cases_chlamydia', 'cases_early_non-primary_non-secondary_syphilis', 'cases_gonorrhea', 'cases_primary_and_secondary_syphilis', 'rate_per_100000_chlamydia', 'rate_per_100000_early_non-primary_non-secondary_syphilis', 'rate_per_100000_gonorrhea', 'rate_per_100000_primary_and_secondary_syphilis', 'cases_female_chlamydia_american_indian_alaska_native', 'cases_female_chlamydia_asian', 'cases_female_chlamydia_black_african_american', 'cases_female_chlamydia_hispanic_latino', 'cases_female_chlamydia_multiracial', 'cases_female_chlamydia_native_hawaiian_other_pacific_islander', 'cases_female_chlamydia_unknown', 'cases_female_chlamydia_white', 'cases_female_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native', 'cases_female_early_non-primary,_non-secondary_syphilis_asian', 'cases_female_early_non-primary,_non-secondary_syphilis_black_african_american', 'cases_female_early_non-primary,_non-secondary_syphilis_hispanic_latino', 'cases_female_early_non-primary,_non-secondary_syphilis_multiracial', 'cases_female_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander', 'cases_female_early_non-primary,_non-secondary_syphilis_unknown', 'cases_female_early_non-primary,_non-secondary_syphilis_white', 'cases_female_gonorrhea_american_indian_alaska_native', 'cases_female_gonorrhea_asian', 'cases_female_gonorrhea_black_african_american', 'cases_female_gonorrhea_hispanic_latino', 'cases_female_gonorrhea_multiracial', 'cases_female_gonorrhea_native_hawaiian_other_pacific_islander', 'cases_female_gonorrhea_unknown', 'cases_female_gonorrhea_white', 'cases_female_primary_and_secondary_syphilis_american_indian_alaska_native', 'cases_female_primary_and_secondary_syphilis_asian', 'cases_female_primary_and_secondary_syphilis_black_african_american', 'cases_female_primary_and_secondary_syphilis_hispanic_latino', 'cases_female_primary_and_secondary_syphilis_multiracial', 'cases_female_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander', 'cases_female_primary_and_secondary_syphilis_unknown', 'cases_female_primary_and_secondary_syphilis_white', 'cases_male_chlamydia_american_indian_alaska_native', 'cases_male_chlamydia_asian', 'cases_male_chlamydia_black_african_american', 'cases_male_chlamydia_hispanic_latino', 'cases_male_chlamydia_multiracial', 'cases_male_chlamydia_native_hawaiian_other_pacific_islander', 'cases_male_chlamydia_unknown', 'cases_male_chlamydia_white', 'cases_male_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native', 'cases_male_early_non-primary,_non-secondary_syphilis_asian', 'cases_male_early_non-primary,_non-secondary_syphilis_black_african_american', 'cases_male_early_non-primary,_non-secondary_syphilis_hispanic_latino', 'cases_male_early_non-primary,_non-secondary_syphilis_multiracial', 'cases_male_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander', 'cases_male_early_non-primary,_non-secondary_syphilis_unknown', 'cases_male_early_non-primary,_non-secondary_syphilis_white', 'cases_male_gonorrhea_american_indian_alaska_native', 'cases_male_gonorrhea_asian', 'cases_male_gonorrhea_black_african_american', 'cases_male_gonorrhea_hispanic_latino', 'cases_male_gonorrhea_multiracial', 'cases_male_gonorrhea_native_hawaiian_other_pacific_islander', 'cases_male_gonorrhea_unknown', 'cases_male_gonorrhea_white', 'cases_male_primary_and_secondary_syphilis_american_indian_alaska_native', 'cases_male_primary_and_secondary_syphilis_asian', 'cases_male_primary_and_secondary_syphilis_black_african_american', 'cases_male_primary_and_secondary_syphilis_hispanic_latino', 'cases_male_primary_and_secondary_syphilis_multiracial', 'cases_male_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander', 'cases_male_primary_and_secondary_syphilis_unknown', 'cases_male_primary_and_secondary_syphilis_white', 'rate_per_100000_female_chlamydia_american_indian_alaska_native', 'rate_per_100000_female_chlamydia_asian', 'rate_per_1 ...
# ['year', 'fips', 'covid_cases', 'county_name']
# ['per_capita_income_2016', 'employment_pop_ratio', 'unemployment_rate', 'pct_ind_agriculture_forestry_fishing_and_hunting_and_mining', 'pct_ind_construction', 'pct_ind_manufacturing', 'pct_ind_wholesale_trade', 'pct_ind_retail_trade', 'pct_ind_transportation_and_warehousing_and_utilities', 'pct_ind_information', 'pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing', 'pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services', 'pct_ind_educational_services_and_health_care_and_social_assistance', 'pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services', 'pct_ind_other_services_except_public_administration', 'pct_ind_public_administration', 'health_insurance_rate', 'poverty_rate', 'year', 'fips', 'per_capita_income_2010', 'per_capita_income_2017', 'per_capita_income_2011', 'per_capita_income_2014', 'pct_employment_status!!population_16_years_and_over!!in_labor_force!!civilian_labor_force!!unemployed', 'per_capita_income_2019', 'per_capita_income_2012', 'per_capita_income_2015', 'per_capita_income_2020', 'per_capita_income_2018', 'per_capita_income_2013']
# ['pct_one_or_more_race', 'pct_one_or_more_race_white', 'pct_one_or_more_race_black', 'pct_one_or_more_race_native_american', 'pct_one_or_more_race_asian', 'pct_one_or_more_race_native_hawaiian_pacific_islander', 'pct_one_or_more_race_other_race', 'pct_ethnicity_hispanic', 'pct_sex_age_under_5', 'pct_sex_age_5_to_9', 'pct_sex_age_10_to_14', 'pct_sex_age_15_to_19', 'pct_sex_age_20_to_24', 'pct_sex_age_25_to_34', 'pct_sex_age_35_to_44', 'pct_sex_age_45_to_54', 'pct_sex_age_55_to_59', 'pct_sex_age_60_to_64', 'pct_sex_age_65_to_74', 'pct_sex_age_75_to_84', 'pct_sex_age_85+', 'median_age', 'pct_sex_age_16+', 'pct_sex_age_18+', 'pct_sex_age_21+', 'pct_sex_age_62+', 'pct_sex_age_65+', 'pct_sex_age_18+_male', 'pct_sex_age_18+_female', 'pct_sex_age_65+_male', 'pct_sex_age_65+_female', 'year', 'total_pop', 'fips', 'pct_sex_age_male', 'pct_sex_age_female', 'pct_white', 'pct_black', 'pct_native_american', 'pct_asian', 'pct_native_hawaiian_pacific_islander', 'pct_other_race']
# ['poverty_rate', 'per_capita_income_2007', 'year', 'fips', 'per_capita_income_2006', 'per_capita_income_2005', 'per_capita_income_2008', 'per_capita_income_2003', 'employed_persons', 'unemployment_rate', 'per_capita_income_2004', 'per_capita_income_2009', 'per_capita_income_2002', 'total_pop']

# %%
df = reduce(lambda  left,right: pd.merge(left, right, on=['year','fips'],
                                            how='outer'), total)
df.head(10)
# Out:
#    year   fips  cases_female_hiv_diagnoses  cases_female_hiv_prevalence  \
# 0  2017  45001                         0.0                         12.0
# 1  2017  45001                         0.0                         12.0
# 2  2017  22001                         0.0                         42.0
# 3  2017  22001                         0.0                         42.0
# 4  2017  51001                         NaN                         34.0
# 5  2017  19001                         0.0                          NaN
# 6  2017  29001                         NaN                          8.0
# 7  2017   8001                         6.0                        166.0
# 8  2017   8001                         6.0                        166.0
# 9  2017  19003                         0.0                          NaN
#
#    cases_female_hiv_viral_suppression  cases_female_linkage_to_hiv_care  \
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# 5                                 NaN                               NaN
# 6                                 NaN                               NaN
# 7                                 NaN                               NaN
# 8                                 NaN                               NaN
# 9                                 NaN                               NaN
#
#    cases_female_prep_coverage_and_number_of_persons_prescribed  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    cases_female_receipt_of_hiv_medical_care  cases_male_hiv_diagnoses  \
# 0                                       NaN                       0.0
# 1                                       NaN                       0.0
# 2                                       NaN                       6.0
# 3                                       NaN                       6.0
# 4                                       NaN                       NaN
# 5                                       NaN                       0.0
# 6                                       NaN                       NaN
# 7                                       NaN                      59.0
# 8                                       NaN                      59.0
# 9                                       NaN                       0.0
#
#    cases_male_hiv_prevalence  ...  per_capita_income_2006  \
# 0                       36.0  ...                     NaN
# 1                       36.0  ...                     NaN
# 2                      101.0  ...                     NaN
# 3                      101.0  ...                     NaN
# 4                       63.0  ...                     NaN
# 5                        NaN  ...                     NaN
# 6                       29.0  ...                     NaN
# 7                      889.0  ...                     NaN
# 8                      889.0  ...                     NaN
# 9                        NaN  ...                     NaN
#
#    per_capita_income_2005  per_capita_income_2008  per_capita_income_2003  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
# 5                     NaN                     NaN                     NaN
# 6                     NaN                     NaN                     NaN
# 7                     NaN                     NaN                     NaN
# 8                     NaN                     NaN                     NaN
# 9                     NaN                     NaN                     NaN
#
#    employed_persons  unemployment_rate_y  per_capita_income_2004  \
# 0               NaN                  NaN                     NaN
# 1               NaN                  NaN                     NaN
# 2               NaN                  NaN                     NaN
# 3               NaN                  NaN                     NaN
# 4               NaN                  NaN                     NaN
# 5               NaN                  NaN                     NaN
# 6               NaN                  NaN                     NaN
# 7               NaN                  NaN                     NaN
# 8               NaN                  NaN                     NaN
# 9               NaN                  NaN                     NaN
#
#    per_capita_income_2009  per_capita_income_2002  total_pop_y
# 0                     NaN                     NaN          NaN
# 1                     NaN                     NaN          NaN
# 2                     NaN                     NaN          NaN
# 3                     NaN                     NaN          NaN
# 4                     NaN                     NaN          NaN
# 5                     NaN                     NaN          NaN
# 6                     NaN                     NaN          NaN
# 7                     NaN                     NaN          NaN
# 8                     NaN                     NaN          NaN
# 9                     NaN                     NaN          NaN
#
# [10 rows x 469 columns]

# %%
list(df.columns)
# Out:
# ['year',
#  'fips',
#  'cases_female_hiv_diagnoses',
#  'cases_female_hiv_prevalence',
#  'cases_female_hiv_viral_suppression',
#  'cases_female_linkage_to_hiv_care',
#  'cases_female_prep_coverage_and_number_of_persons_prescribed',
#  'cases_female_receipt_of_hiv_medical_care',
#  'cases_male_hiv_diagnoses',
#  'cases_male_hiv_prevalence',
#  'cases_male_hiv_viral_suppression',
#  'cases_male_linkage_to_hiv_care',
#  'cases_male_prep_coverage_and_number_of_persons_prescribed',
#  'cases_male_receipt_of_hiv_medical_care',
#  'percent_female_hiv_viral_suppression',
#  'percent_female_linkage_to_hiv_care',
#  'percent_female_prep_coverage_and_number_of_persons_prescribed',
#  'percent_female_receipt_of_hiv_medical_care',
#  'percent_male_hiv_viral_suppression',
#  'percent_male_linkage_to_hiv_care',
#  'percent_male_prep_coverage_and_number_of_persons_prescribed',
#  'percent_male_receipt_of_hiv_medical_care',
#  'rate_per_100000_female_hiv_diagnoses',
#  'rate_per_100000_female_hiv_prevalence',
#  'rate_per_100000_male_hiv_diagnoses',
#  'rate_per_100000_male_hiv_prevalence',
#  'cases_female_chlamydia_0_14',
#  'cases_female_chlamydia_15_19',
#  'cases_female_chlamydia_20_24',
#  'cases_female_chlamydia_25_29',
#  'cases_female_chlamydia_30_34',
#  'cases_female_chlamydia_35_39',
#  'cases_female_chlamydia_40_44',
#  'cases_female_chlamydia_45_54',
#  'cases_female_chlamydia_55_64',
#  'cases_female_chlamydia_65+',
#  'cases_female_chlamydia_unknown_x',
#  'cases_female_early non_primary, non_secondary syphilis_0_14',
#  'cases_female_early non_primary, non_secondary syphilis_15_19',
#  'cases_female_early non_primary, non_secondary syphilis_20_24',
#  'cases_female_early non_primary, non_secondary syphilis_25_29',
#  'cases_female_early non_primary, non_secondary syphilis_30_34',
#  'cases_female_early non_primary, non_secondary syphilis_35_39',
#  'cases_female_early non_primary, non_secondary syphilis_40_44',
#  'cases_female_early non_primary, non_secondary syphilis_45_54',
#  'cases_female_early non_primary, non_secondary syphilis_55_64',
#  'cases_female_early non_primary, non_secondary syphilis_65+',
#  'cases_female_early non_primary, non_secondary syphilis_unknown',
#  'cases_female_gonorrhea_0_14',
#  'cases_female_gonorrhea_15_19',
#  'cases_female_gonorrhea_20_24',
#  'cases_female_gonorrhea_25_29',
#  'cases_female_gonorrhea_30_34',
#  'cases_female_gonorrhea_35_39',
#  'cases_female_gonorrhea_40_44',
#  'cases_female_gonorrhea_45_54',
#  'cases_female_gonorrhea_55_64',
#  'cases_female_gonorrhea_65+',
#  'cases_female_gonorrhea_unknown_x',
#  'cases_female_primary and secondary syphilis_0_14',
#  'cases_female_primary and secondary syphilis_15_19',
#  'cases_female_primary and secondary syphilis_20_24',
#  'cases_female_primary and secondary syphilis_25_29',
#  'cases_female_primary and secondary syphilis_30_34',
#  'cases_female_primary and secondary syphilis_35_39',
#  'cases_female_primary and secondary syphilis_40_44',
#  'cases_female_primary and secondary syphilis_45_54',
#  'cases_female_primary and secondary syphilis_55_64',
#  'cases_female_primary and secondary syphilis_65+',
#  'cases_female_primary and secondary syphilis_unknown',
#  'cases_male_chlamydia_0_14',
#  'cases_male_chlamydia_15_19',
#  'cases_male_chlamydia_20_24',
#  'cases_male_chlamydia_25_29',
#  'cases_male_chlamydia_30_34',
#  'cases_male_chlamydia_35_39',
#  'cases_male_chlamydia_40_44',
#  'cases_male_chlamydia_45_54',
#  'cases_male_chlamydia_55_64',
#  'cases_male_chlamydia_65+',
#  'cases_male_chlamydia_unknown_x',
#  'cases_male_early non_primary, non_secondary syphilis_0_14',
#  'cases_male_early non_primary, non_secondary syphilis_15_19',
#  'cases_male_early non_primary, non_secondary syphilis_20_24',
#  'cases_male_early non_primary, non_secondary syphilis_25_29',
#  'cases_male_early non_primary, non_secondary syphilis_30_34',
#  'cases_male_early non_primary, non_secondary syphilis_35_39',
#  'cases_male_early non_primary, non_secondary syphilis_40_44',
#  'cases_male_early non_primary, non_secondary syphilis_45_54',
#  'cases_male_early non_primary, non_secondary syphilis_55_64',
#  'cases_male_early non_primary, non_secondary syphilis_65+',
#  'cases_male_early non_primary, non_secondary syphilis_unknown',
#  'cases_male_gonorrhea_0_14',
#  'cases_male_gonorrhea_15_19',
#  'cases_male_gonorrhea_20_24',
#  'cases_male_gonorrhea_25_29',
#  'cases_male_gonorrhea_30_34',
#  'cases_male_gonorrhea_35_39',
#  'cases_male_gonorrhea_40_44',
#  'cases_male_gonorrhea_45_54',
#  'cases_male_gonorrhea_55_64',
#  'cases_male_gonorrhea_65+',
#  'cases_male_gonorrhea_unknown_x',
#  'cases_male_primary and secondary syphilis_0_14',
#  'cases_male_primary and secondary syphilis_15_19',
#  'cases_male_primary and secondary syphilis_20_24',
#  'cases_male_primary and secondary syphilis_25_29',
#  'cases_male_primary and secondary syphilis_30_34',
#  'cases_male_primary and secondary syphilis_35_39',
#  'cases_male_primary and secondary syphilis_40_44',
#  'cases_male_primary and secondary syphilis_45_54',
#  'cases_male_primary and secondary syphilis_55_64',
#  'cases_male_primary and secondary syphilis_65+',
#  'cases_male_primary and secondary syphilis_unknown',
#  'rateper100000_female_chlamydia_0_14',
#  'rateper100000_female_chlamydia_15_19',
#  'rateper100000_female_chlamydia_20_24',
#  'rateper100000_female_chlamydia_25_29',
#  'rateper100000_female_chlamydia_30_34',
#  'rateper100000_female_chlamydia_35_39',
#  'rateper100000_female_chlamydia_40_44',
#  'rateper100000_female_chlamydia_45_54',
#  'rateper100000_female_chlamydia_55_64',
#  'rateper100000_female_chlamydia_65+',
#  'rateper100000_female_early non_primary, non_secondary syphilis_0_14',
#  'rateper100000_female_early non_primary, non_secondary syphilis_15_19',
#  'rateper100000_female_early non_primary, non_secondary syphilis_20_24',
#  'rateper100000_female_early non_primary, non_secondary syphilis_25_29',
#  'rateper100000_female_early non_primary, non_secondary syphilis_30_34',
#  'rateper100000_female_early non_primary, non_secondary syphilis_35_39',
#  'rateper100000_female_early non_primary, non_secondary syphilis_40_44',
#  'rateper100000_female_early non_primary, non_secondary syphilis_45_54',
#  'rateper100000_female_early non_primary, non_secondary syphilis_55_64',
#  'rateper100000_female_early non_primary, non_secondary syphilis_65+',
#  'rateper100000_female_gonorrhea_0_14',
#  'rateper100000_female_gonorrhea_15_19',
#  'rateper100000_female_gonorrhea_20_24',
#  'rateper100000_female_gonorrhea_25_29',
#  'rateper100000_female_gonorrhea_30_34',
#  'rateper100000_female_gonorrhea_35_39',
#  'rateper100000_female_gonorrhea_40_44',
#  'rateper100000_female_gonorrhea_45_54',
#  'rateper100000_female_gonorrhea_55_64',
#  'rateper100000_female_gonorrhea_65+',
#  'rateper100000_female_primary and secondary syphilis_0_14',
#  'rateper100000_female_primary and secondary syphilis_15_19',
#  'rateper100000_female_primary and secondary syphilis_20_24',
#  'rateper100000_female_primary and secondary syphilis_25_29',
#  'rateper100000_female_primary and secondary syphilis_30_34',
#  'rateper100000_female_primary and secondary syphilis_35_39',
#  'rateper100000_female_primary and secondary syphilis_40_44',
#  'rateper100000_female_primary and secondary syphilis_45_54',
#  'rateper100000_female_primary and secondary syphilis_55_64',
#  'rateper100000_female_primary and secondary syphilis_65+',
#  'rateper100000_male_chlamydia_0_14',
#  'rateper100000_male_chlamydia_15_19',
#  'rateper100000_male_chlamydia_20_24',
#  'rateper100000_male_chlamydia_25_29',
#  'rateper100000_male_chlamydia_30_34',
#  'rateper100000_male_chlamydia_35_39',
#  'rateper100000_male_chlamydia_40_44',
#  'rateper100000_male_chlamydia_45_54',
#  'rateper100000_male_chlamydia_55_64',
#  'rateper100000_male_chlamydia_65+',
#  'rateper100000_male_early non_primary, non_secondary syphilis_0_14',
#  'rateper100000_male_early non_primary, non_secondary syphilis_15_19',
#  'rateper100000_male_early non_primary, non_secondary syphilis_20_24',
#  'rateper100000_male_early non_primary, non_secondary syphilis_25_29',
#  'rateper100000_male_early non_primary, non_secondary syphilis_30_34',
#  'rateper100000_male_early non_primary, non_secondary syphilis_35_39',
#  'rateper100000_male_early non_primary, non_secondary syphilis_40_44',
#  'rateper100000_male_early non_primary, non_secondary syphilis_45_54',
#  'rateper100000_male_early non_primary, non_secondary syphilis_55_64',
#  'rateper100000_male_early non_primary, non_secondary syphilis_65+',
#  'rateper100000_male_gonorrhea_0_14',
#  'rateper100000_male_gonorrhea_15_19',
#  'rateper100000_male_gonorrhea_20_24',
#  'rateper100000_male_gonorrhea_25_29',
#  'rateper100000_male_gonorrhea_30_34',
#  'rateper100000_male_gonorrhea_35_39',
#  'rateper100000_male_gonorrhea_40_44',
#  'rateper100000_male_gonorrhea_45_54',
#  'rateper100000_male_gonorrhea_55_64',
#  'rateper100000_male_gonorrhea_65+',
#  'rateper100000_male_primary and secondary syphilis_0_14',
#  'rateper100000_male_primary and secondary syphilis_15_19',
#  'rateper100000_male_primary and secondary syphilis_20_24',
#  'rateper100000_male_primary and secondary syphilis_25_29',
#  'rateper100000_male_primary and secondary syphilis_30_34',
#  'rateper100000_male_primary and secondary syphilis_35_39',
#  'rateper100000_male_primary and secondary syphilis_40_44',
#  'rateper100000_male_primary and secondary syphilis_45_54',
#  'rateper100000_male_primary and secondary syphilis_55_64',
#  'rateper100000_male_primary and secondary syphilis_65+',
#  'cases_13-24_HIV diagnoses',
#  'cases_13-24_HIV prevalence',
#  'cases_13-24_HIV viral suppression',
#  'cases_13-24_Linkage to HIV care',
#  'cases_13-24_PrEP coverage and number of persons prescribed',
#  'cases_13-24_Receipt of HIV medical care',
#  'cases_25-34_HIV diagnoses',
#  'cases_25-34_HIV prevalence',
#  'cases_25-34_HIV viral suppression',
#  'cases_25-34_Linkage to HIV care',
#  'cases_25-34_PrEP coverage and number of persons prescribed',
#  'cases_25-34_Receipt of HIV medical care',
#  'cases_35-44_HIV diagnoses',
#  'cases_35-44_HIV prevalence',
#  'cases_35-44_HIV viral suppression',
#  'cases_35-44_Linkage to HIV care',
#  'cases_35-44_PrEP coverage and number of persons prescribed',
#  'cases_35-44_Receipt of HIV medical care',
#  'cases_45-54_HIV diagnoses',
#  'cases_45-54_HIV prevalence',
#  'cases_45-54_HIV viral suppression',
#  'cases_45-54_Linkage to HIV care',
#  'cases_45-54_PrEP coverage and number of persons prescribed',
#  'cases_45-54_Receipt of HIV medical care',
#  'cases_55+_HIV diagnoses',
#  'cases_55+_HIV prevalence',
#  'cases_55+_HIV viral suppression',
#  'cases_55+_Linkage to HIV care',
#  'cases_55+_PrEP coverage and number of persons prescribed',
#  'cases_55+_Receipt of HIV medical care',
#  'percent_13-24_HIV viral suppression',
#  'percent_13-24_Linkage to HIV care',
#  'percent_13-24_PrEP coverage and number of persons prescribed',
#  'percent_13-24_Receipt of HIV medical care',
#  'percent_25-34_HIV viral suppression',
#  'percent_25-34_Linkage to HIV care',
#  'percent_25-34_PrEP coverage and number of persons prescribed',
#  'percent_25-34_Receipt of HIV medical care',
#  'percent_35-44_HIV viral suppression',
#  'percent_35-44_Linkage to HIV care',
#  'percent_35-44_PrEP coverage and number of persons prescribed',
#  'percent_35-44_Receipt of HIV medical care',
#  'percent_45-54_HIV viral suppression',
#  'percent_45-54_Linkage to HIV care',
#  'percent_45-54_PrEP coverage and number of persons prescribed',
#  'percent_45-54_Receipt of HIV medical care',
#  'percent_55+_HIV viral suppression',
#  'percent_55+_Linkage to HIV care',
#  'percent_55+_PrEP coverage and number of persons prescribed',
#  'percent_55+_Receipt of HIV medical care',
#  'ratePer100000_13-24_HIV diagnoses',
#  'ratePer100000_13-24_HIV prevalence',
#  'ratePer100000_25-34_HIV diagnoses',
#  'ratePer100000_25-34_HIV prevalence',
#  'ratePer100000_35-44_HIV diagnoses',
#  'ratePer100000_35-44_HIV prevalence',
#  'ratePer100000_45-54_HIV diagnoses',
#  'ratePer100000_45-54_HIV prevalence',
#  'ratePer100000_55+_HIV diagnoses',
#  'ratePer100000_55+_HIV prevalence',
#  'cases_HIV diagnoses',
#  'cases_HIV prevalence',
#  'ratePer100000_HIV diagnoses',
#  'ratePer100000_HIV prevalence',
#  'cases_chlamydia',
#  'cases_early_non-primary_non-secondary_syphilis',
#  'cases_gonorrhea',
#  'cases_primary_and_secondary_syphilis',
#  'rate_per_100000_chlamydia',
#  'rate_per_100000_early_non-primary_non-secondary_syphilis',
#  'rate_per_100000_gonorrhea',
#  'rate_per_100000_primary_and_secondary_syphilis',
#  'cases_female_chlamydia_american_indian_alaska_native',
#  'cases_female_chlamydia_asian',
#  'cases_female_chlamydia_black_african_american',
#  'cases_female_chlamydia_hispanic_latino',
#  'cases_female_chlamydia_multiracial',
#  'cases_female_chlamydia_native_hawaiian_other_pacific_islander',
#  'cases_female_chlamydia_unknown_y',
#  'cases_female_chlamydia_white',
#  'cases_female_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native',
#  'cases_female_early_non-primary,_non-secondary_syphilis_asian',
#  'cases_female_early_non-primary,_non-secondary_syphilis_black_african_american',
#  'cases_female_early_non-primary,_non-secondary_syphilis_hispanic_latino',
#  'cases_female_early_non-primary,_non-secondary_syphilis_multiracial',
#  'cases_female_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'cases_female_early_non-primary,_non-secondary_syphilis_unknown',
#  'cases_female_early_non-primary,_non-secondary_syphilis_white',
#  'cases_female_gonorrhea_american_indian_alaska_native',
#  'cases_female_gonorrhea_asian',
#  'cases_female_gonorrhea_black_african_american',
#  'cases_female_gonorrhea_hispanic_latino',
#  'cases_female_gonorrhea_multiracial',
#  'cases_female_gonorrhea_native_hawaiian_other_pacific_islander',
#  'cases_female_gonorrhea_unknown_y',
#  'cases_female_gonorrhea_white',
#  'cases_female_primary_and_secondary_syphilis_american_indian_alaska_native',
#  'cases_female_primary_and_secondary_syphilis_asian',
#  'cases_female_primary_and_secondary_syphilis_black_african_american',
#  'cases_female_primary_and_secondary_syphilis_hispanic_latino',
#  'cases_female_primary_and_secondary_syphilis_multiracial',
#  'cases_female_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'cases_female_primary_and_secondary_syphilis_unknown',
#  'cases_female_primary_and_secondary_syphilis_white',
#  'cases_male_chlamydia_american_indian_alaska_native',
#  'cases_male_chlamydia_asian',
#  'cases_male_chlamydia_black_african_american',
#  'cases_male_chlamydia_hispanic_latino',
#  'cases_male_chlamydia_multiracial',
#  'cases_male_chlamydia_native_hawaiian_other_pacific_islander',
#  'cases_male_chlamydia_unknown_y',
#  'cases_male_chlamydia_white',
#  'cases_male_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native',
#  'cases_male_early_non-primary,_non-secondary_syphilis_asian',
#  'cases_male_early_non-primary,_non-secondary_syphilis_black_african_american',
#  'cases_male_early_non-primary,_non-secondary_syphilis_hispanic_latino',
#  'cases_male_early_non-primary,_non-secondary_syphilis_multiracial',
#  'cases_male_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'cases_male_early_non-primary,_non-secondary_syphilis_unknown',
#  'cases_male_early_non-primary,_non-secondary_syphilis_white',
#  'cases_male_gonorrhea_american_indian_alaska_native',
#  'cases_male_gonorrhea_asian',
#  'cases_male_gonorrhea_black_african_american',
#  'cases_male_gonorrhea_hispanic_latino',
#  'cases_male_gonorrhea_multiracial',
#  'cases_male_gonorrhea_native_hawaiian_other_pacific_islander',
#  'cases_male_gonorrhea_unknown_y',
#  'cases_male_gonorrhea_white',
#  'cases_male_primary_and_secondary_syphilis_american_indian_alaska_native',
#  'cases_male_primary_and_secondary_syphilis_asian',
#  'cases_male_primary_and_secondary_syphilis_black_african_american',
#  'cases_male_primary_and_secondary_syphilis_hispanic_latino',
#  'cases_male_primary_and_secondary_syphilis_multiracial',
#  'cases_male_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'cases_male_primary_and_secondary_syphilis_unknown',
#  'cases_male_primary_and_secondary_syphilis_white',
#  'rate_per_100000_female_chlamydia_american_indian_alaska_native',
#  'rate_per_100000_female_chlamydia_asian',
#  'rate_per_100000_female_chlamydia_black_african_american',
#  'rate_per_100000_female_chlamydia_hispanic_latino',
#  'rate_per_100000_female_chlamydia_multiracial',
#  'rate_per_100000_female_chlamydia_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_female_chlamydia_white',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_asian',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_black_african_american',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_hispanic_latino',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_multiracial',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_female_early_non-primary,_non-secondary_syphilis_white',
#  'rate_per_100000_female_gonorrhea_american_indian_alaska_native',
#  'rate_per_100000_female_gonorrhea_asian',
#  'rate_per_100000_female_gonorrhea_black_african_american',
#  'rate_per_100000_female_gonorrhea_hispanic_latino',
#  'rate_per_100000_female_gonorrhea_multiracial',
#  'rate_per_100000_female_gonorrhea_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_female_gonorrhea_white',
#  'rate_per_100000_female_primary_and_secondary_syphilis_american_indian_alaska_native',
#  'rate_per_100000_female_primary_and_secondary_syphilis_asian',
#  'rate_per_100000_female_primary_and_secondary_syphilis_black_african_american',
#  'rate_per_100000_female_primary_and_secondary_syphilis_hispanic_latino',
#  'rate_per_100000_female_primary_and_secondary_syphilis_multiracial',
#  'rate_per_100000_female_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_female_primary_and_secondary_syphilis_white',
#  'rate_per_100000_male_chlamydia_american_indian_alaska_native',
#  'rate_per_100000_male_chlamydia_asian',
#  'rate_per_100000_male_chlamydia_black_african_american',
#  'rate_per_100000_male_chlamydia_hispanic_latino',
#  'rate_per_100000_male_chlamydia_multiracial',
#  'rate_per_100000_male_chlamydia_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_male_chlamydia_white',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_american_indian_alaska_native',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_asian',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_black_african_american',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_hispanic_latino',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_multiracial',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_male_early_non-primary,_non-secondary_syphilis_white',
#  'rate_per_100000_male_gonorrhea_american_indian_alaska_native',
#  'rate_per_100000_male_gonorrhea_asian',
#  'rate_per_100000_male_gonorrhea_black_african_american',
#  'rate_per_100000_male_gonorrhea_hispanic_latino',
#  'rate_per_100000_male_gonorrhea_multiracial',
#  'rate_per_100000_male_gonorrhea_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_male_gonorrhea_white',
#  'rate_per_100000_male_primary_and_secondary_syphilis_american_indian_alaska_native',
#  'rate_per_100000_male_primary_and_secondary_syphilis_asian',
#  'rate_per_100000_male_primary_and_secondary_syphilis_black_african_american',
#  'rate_per_100000_male_primary_and_secondary_syphilis_hispanic_latino',
#  'rate_per_100000_male_primary_and_secondary_syphilis_multiracial',
#  'rate_per_100000_male_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander',
#  'rate_per_100000_male_primary_and_secondary_syphilis_white',
#  'covid_cases',
#  'county_name',
#  'per_capita_income_2016',
#  'employment_pop_ratio',
#  'unemployment_rate_x',
#  'pct_ind_agriculture_forestry_fishing_and_hunting_and_mining',
#  'pct_ind_construction',
#  'pct_ind_manufacturing',
#  'pct_ind_wholesale_trade',
#  'pct_ind_retail_trade',
#  'pct_ind_transportation_and_warehousing_and_utilities',
#  'pct_ind_information',
#  'pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing',
#  'pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services',
#  'pct_ind_educational_services_and_health_care_and_social_assistance',
#  'pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services',
#  'pct_ind_other_services_except_public_administration',
#  'pct_ind_public_administration',
#  'health_insurance_rate',
#  'poverty_rate_x',
#  'per_capita_income_2010',
#  'per_capita_income_2017',
#  'per_capita_income_2011',
#  'per_capita_income_2014',
#  'pct_employment_status!!population_16_years_and_over!!in_labor_force!!civilian_labor_force!!unemployed',
#  'per_capita_income_2019',
#  'per_capita_income_2012',
#  'per_capita_income_2015',
#  'per_capita_income_2020',
#  'per_capita_income_2018',
#  'per_capita_income_2013',
#  'pct_one_or_more_race',
#  'pct_one_or_more_race_white',
#  'pct_one_or_more_race_black',
#  'pct_one_or_more_race_native_american',
#  'pct_one_or_more_race_asian',
#  'pct_one_or_more_race_native_hawaiian_pacific_islander',
#  'pct_one_or_more_race_other_race',
#  'pct_ethnicity_hispanic',
#  'pct_sex_age_under_5',
#  'pct_sex_age_5_to_9',
#  'pct_sex_age_10_to_14',
#  'pct_sex_age_15_to_19',
#  'pct_sex_age_20_to_24',
#  'pct_sex_age_25_to_34',
#  'pct_sex_age_35_to_44',
#  'pct_sex_age_45_to_54',
#  'pct_sex_age_55_to_59',
#  'pct_sex_age_60_to_64',
#  'pct_sex_age_65_to_74',
#  'pct_sex_age_75_to_84',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_16+',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_sex_age_18+_male',
#  'pct_sex_age_18+_female',
#  'pct_sex_age_65+_male',
#  'pct_sex_age_65+_female',
#  'total_pop_x',
#  'pct_sex_age_male',
#  'pct_sex_age_female',
#  'pct_white',
#  'pct_black',
#  'pct_native_american',
#  'pct_asian',
#  'pct_native_hawaiian_pacific_islander',
#  'pct_other_race',
#  'poverty_rate_y',
#  'per_capita_income_2007',
#  'per_capita_income_2006',
#  'per_capita_income_2005',
#  'per_capita_income_2008',
#  'per_capita_income_2003',
#  'employed_persons',
#  'unemployment_rate_y',
#  'per_capita_income_2004',
#  'per_capita_income_2009',
#  'per_capita_income_2002',
#  'total_pop_y']

# %%
path = '../Data/Clean/ACS'
cov = []

cov.append(pd.read_csv(os.path.join(path, 'ACSDP032020_clean.csv'), index_col = 0).columns.to_list())
cov.append(pd.read_csv(os.path.join(path, 'ACSDP052020_clean.csv'), index_col = 0).columns.to_list())

# %%
print(type(cov))
print(cov)
# Out:
# <class 'list'>
# [['per_capita_income_2020', 'employment_pop_ratio', 'unemployment_rate', 'pct_ind_agriculture_forestry_fishing_and_hunting_and_mining', 'pct_ind_construction', 'pct_ind_manufacturing', 'pct_ind_wholesale_trade', 'pct_ind_retail_trade', 'pct_ind_transportation_and_warehousing_and_utilities', 'pct_ind_information', 'pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing', 'pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services', 'pct_ind_educational_services_and_health_care_and_social_assistance', 'pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services', 'pct_ind_other_services_except_public_administration', 'pct_ind_public_administration', 'health_insurance_rate', 'poverty_rate', 'id', 'geographic_area_name', 'year', 'fips'], ['pct_sex_age_under_5', 'pct_sex_age_5_to_9', 'pct_sex_age_10_to_14', 'pct_sex_age_15_to_19', 'pct_sex_age_20_to_24', 'pct_sex_age_25_to_34', 'pct_sex_age_35_to_44', 'pct_sex_age_45_to_54', 'pct_sex_age_55_to_59', 'pct_sex_age_60_to_64', 'pct_sex_age_65_to_74', 'pct_sex_age_75_to_84', 'pct_sex_age_85+', 'median_age', 'pct_sex_age_16+', 'pct_sex_age_18+', 'pct_sex_age_21+', 'pct_sex_age_62+', 'pct_sex_age_65+', 'pct_sex_age_18+_male', 'pct_sex_age_18+_female', 'pct_sex_age_65+_male', 'pct_sex_age_65+_female', 'pct_one_or_more_race', 'pct_one_or_more_race_white', 'pct_one_or_more_race_black', 'pct_one_or_more_race_native_american', 'pct_one_or_more_race_asian', 'pct_one_or_more_race_native_hawaiian_pacific_islander', 'pct_one_or_more_race_other_race', 'pct_ethnicity_hispanic', 'id', 'Geographic Area Name', 'year', 'total_pop', 'fips']]

# %%
db_columns_list = ['col1', 'col2', 'col3']
df=pd.DataFrame({
    'col1':[1,2],
    'col3':[3,4]
})

## Solution
df[set(df.columns).intersection(set(db_columns_list))]
# Out:
# /var/folders/jb/2grr3hjx7fng_kz01_rqpskm0000gn/T/ipykernel_10611/566397074.py:8: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[set(df.columns).intersection(set(db_columns_list))]
#    col3  col1
# 0     3     1
# 1     4     2

# %%
# Improved version with the help of `Mustafa Aydın`
df_list = [x for xs in cov for x in xs]
print(df_list)
#df[df.columns.intersection(df_list)]
df[df[df_list]]
# Out:
# ['per_capita_income_2020', 'employment_pop_ratio', 'unemployment_rate', 'pct_ind_agriculture_forestry_fishing_and_hunting_and_mining', 'pct_ind_construction', 'pct_ind_manufacturing', 'pct_ind_wholesale_trade', 'pct_ind_retail_trade', 'pct_ind_transportation_and_warehousing_and_utilities', 'pct_ind_information', 'pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing', 'pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services', 'pct_ind_educational_services_and_health_care_and_social_assistance', 'pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services', 'pct_ind_other_services_except_public_administration', 'pct_ind_public_administration', 'health_insurance_rate', 'poverty_rate', 'id', 'geographic_area_name', 'year', 'fips', 'pct_sex_age_under_5', 'pct_sex_age_5_to_9', 'pct_sex_age_10_to_14', 'pct_sex_age_15_to_19', 'pct_sex_age_20_to_24', 'pct_sex_age_25_to_34', 'pct_sex_age_35_to_44', 'pct_sex_age_45_to_54', 'pct_sex_age_55_to_59', 'pct_sex_age_60_to_64', 'pct_sex_age_65_to_74', 'pct_sex_age_75_to_84', 'pct_sex_age_85+', 'median_age', 'pct_sex_age_16+', 'pct_sex_age_18+', 'pct_sex_age_21+', 'pct_sex_age_62+', 'pct_sex_age_65+', 'pct_sex_age_18+_male', 'pct_sex_age_18+_female', 'pct_sex_age_65+_male', 'pct_sex_age_65+_female', 'pct_one_or_more_race', 'pct_one_or_more_race_white', 'pct_one_or_more_race_black', 'pct_one_or_more_race_native_american', 'pct_one_or_more_race_asian', 'pct_one_or_more_race_native_hawaiian_pacific_islander', 'pct_one_or_more_race_other_race', 'pct_ethnicity_hispanic', 'id', 'Geographic Area Name', 'year', 'total_pop', 'fips']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [94], in <cell line: 5>()
#       3 print(df_list)
#       4 #df[df.columns.intersection(df_list)]
# ----> 5 df[df[df_list]]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['per_capita_income_2020', 'employment_pop_ratio', 'unemployment_rate',\n       'pct_ind_agriculture_forestry_fishing_and_hunting_and_mining',\n       'pct_ind_construction', 'pct_ind_manufacturing',\n       'pct_ind_wholesale_trade', 'pct_ind_retail_trade',\n       'pct_ind_transportation_and_warehousing_and_utilities',\n       'pct_ind_information',\n       'pct_ind_finance_and_insurance_and_real_estate_and_rental_and_leasing',\n       'pct_ind_professional_scientific_and_management_and_administrative_and_waste_management_services',\n       'pct_ind_educational_services_and_health_care_and_social_assistance',\n       'pct_ind_arts_entertainment_and_recreation_and_accommodation_and_food_services',\n       'pct_ind_other_services_except_public_administration',\n       'pct_ind_public_administration', 'health_insurance_rate',\n       'poverty_rate', 'id', 'geographic_area_name', 'year', 'fips',\n       'pct_sex_age_under_5', 'pct_sex_age_5_to_9', 'pct_sex_age_10_to_14',\n       'pct_sex_age_15_to_19', 'pct_sex_age_20_to_24', 'pct_sex_age_25_to_34',\n       'pct_sex_age_35_to_44', 'pct_sex_age_45_to_54', 'pct_sex_age_55_to_59',\n       'pct_sex_age_60_to_64', 'pct_sex_age_65_to_74', 'pct_sex_age_75_to_84',\n       'pct_sex_age_85+', 'median_age', 'pct_sex_age_16+', 'pct_sex_age_18+',\n       'pct_sex_age_21+', 'pct_sex_age_62+', 'pct_sex_age_65+',\n       'pct_sex_age_18+_male', 'pct_sex_age_18+_female',\n       'pct_sex_age_65+_male', 'pct_sex_age_65+_female',\n       'pct_one_or_more_race', 'pct_one_or_more_race_white',\n       'pct_one_or_more_race_black', 'pct_one_or_more_race_native_american',\n       'pct_one_or_more_race_asian',\n       'pct_one_or_more_race_native_hawaiian_pacific_islander',\n       'pct_one_or_more_race_other_race', 'pct_ethnicity_hispanic', 'id',\n       'Geographic Area Name', 'year', 'total_pop', 'fips'],\n      dtype='object')] are in the [columns]"
