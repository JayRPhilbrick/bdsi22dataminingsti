# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../Data/Final/pred_vals_errors_2020_cov.csv")
df = df.drop(columns = "Unnamed: 0")
df.head()
# Out:
#     fips  act_values_chlamydia  pred_values_chlamydia  errors_chlamydia  \
# 0  45001                  99.0             112.222222        -13.222222
# 1  22001                 369.0             332.833892         36.166108
# 2  51001                 210.0             128.383234         81.616766
# 3  16001                2163.0            1935.843521        227.156479
# 4  19001                  24.0              13.819354         10.180646
#
#    act_values_gonorrhea  pred_values_gonorrhea  errors_gonorrhea  \
# 0                  69.0              45.888889         23.111111
# 1                 140.0              36.554362        103.445638
# 2                  66.0              12.736965         53.263035
# 3                 601.0             242.210602        358.789398
# 4                   7.0              -0.872647          7.872647
#
#    act_values_early_non-primary_non-secondary_syphilis  \
# 0                                                2.0
# 1                                                2.0
# 2                                                0.0
# 3                                               23.0
# 4                                                0.0
#
#    pred_values_early_non-primary_non-secondary_syphilis  \
# 0                                           0.562562
# 1                                           1.390984
# 2                                           0.154555
# 3                                           9.812142
# 4                                           0.000000
#
#    errors_early_non-primary_non-secondary_syphilis  \
# 0                                         1.437438
# 1                                         0.609016
# 2                                        -0.154555
# 3                                        13.187858
# 4                                         0.000000
#
#    act_values_primary_and_secondary_syphilis  \
# 0                                        4.0
# 1                                       11.0
# 2                                        2.0
# 3                                       24.0
# 4                                        0.0
#
#    pred_values_primary_and_secondary_syphilis  \
# 0                                1.115524e+00
# 1                                2.359747e+00
# 2                               -2.235126e-02
# 3                                9.763654e+00
# 4                               -2.170433e-19
#
#    errors_early_primary_and_secondary_syphilis  total_pop  \
# 0                                 2.884476e+00    24582.0
# 1                                 8.640253e+00    62371.0
# 2                                 2.022351e+00    32560.0
# 3                                 1.423635e+01   469473.0
# 4                                 2.170433e-19     7048.0
#
#    adj_errors_gonorrhea  adj_errors_chlamydia  \
# 0              0.000940             -0.000538
# 1              0.001659              0.000580
# 2              0.001636              0.002507
# 3              0.000764              0.000484
# 4              0.001117              0.001444
#
#    adj_errors_early_non-primary_non-secondary_syphilis  \
# 0                                           0.000058
# 1                                           0.000010
# 2                                          -0.000005
# 3                                           0.000028
# 4                                           0.000000
#
#    adj_errors_early_primary_and_secondary_syphilis
# 0                                     1.173410e-04
# 1                                     1.385300e-04
# 2                                     6.211153e-05
# 3                                     3.032410e-05
# 4                                     3.079502e-23

# %%
print("Number of missing Chlamydia cases: " + str(df["errors_chlamydia"].sum(axis=0)))
print("Number of missing Gonorrhea cases: " + str(df["errors_gonorrhea"].sum(axis=0)))
print("Number of missing Early Syphilis cases: " + str((df["errors_early_non-primary_non-secondary_syphilis"].sum(axis=0))))
print("Number of missing Late Syphilis cases: " + str((df["errors_early_primary_and_secondary_syphilis"].sum(axis=0))))
# Out:
# Number of missing Chlamydia cases: 389143.71817504853
# Number of missing Gonorrhea cases: 272236.4700533902
# Number of missing Early Syphilis cases: 21035.160233461494
# Number of missing Late Syphilis cases: 21665.572728563166
