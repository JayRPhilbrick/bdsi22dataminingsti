# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("..\Data\Raw\ACS\ACSDP052010.csv", skiprows=1)
df["year"] = 2010
df.head(5)
# Out:
# C:\Users\philb\AppData\Local\Temp\ipykernel_3616\3672535365.py:1: DtypeWarning: Columns (103,107) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("..\Data\Raw\ACS\ACSDP052010.csv", skiprows=1)
#                id  Estimate!!SEX AND AGE!!Total population  \
# 0  0500000US01001                                    53155
# 1  0500000US01003                                   175791
# 2  0500000US01005                                    27699
# 3  0500000US01007                                    22610
# 4  0500000US01009                                    56692
#
#   Estimate Margin of Error!!SEX AND AGE!!Total population  \
# 0                                              *****
# 1                                              *****
# 2                                              *****
# 3                                              *****
# 4                                              *****
#
#    Percent!!SEX AND AGE!!Total population  \
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'Estimate!!SEX AND AGE!!Total population',
#  'Estimate Margin of Error!!SEX AND AGE!!Total population',
#  'Percent!!SEX AND AGE!!Total population',
#  'Percent Margin of Error!!SEX AND AGE!!Total population',
#  'Estimate!!SEX AND AGE!!Male',
#  'Estimate Margin of Error!!SEX AND AGE!!Male',
#  'Percent!!SEX AND AGE!!Male',
#  'Percent Margin of Error!!SEX AND AGE!!Male',
#  'Estimate!!SEX AND AGE!!Female',
#  'Estimate Margin of Error!!SEX AND AGE!!Female',
#  'Percent!!SEX AND AGE!!Female',
#  'Percent Margin of Error!!SEX AND AGE!!Female',
#  'Estimate!!SEX AND AGE!!Under 5 years',
#  'Estimate Margin of Error!!SEX AND AGE!!Under 5 years',
#  'Percent!!SEX AND AGE!!Under 5 years',
#  'Percent Margin of Error!!SEX AND AGE!!Under 5 years',
#  'Estimate!!SEX AND AGE!!5 to 9 years',
#  'Estimate Margin of Error!!SEX AND AGE!!5 to 9 years',
#  'Percent!!SEX AND AGE!!5 to 9 years',
#  'Percent Margin of Error!!SEX AND AGE!!5 to 9 years',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='Margin of Error')))]
df.head(5)
# Out:
#                id  Estimate!!SEX AND AGE!!Total population  \
# 0  0500000US01001                                    53155
# 1  0500000US01003                                   175791
# 2  0500000US01005                                    27699
# 3  0500000US01007                                    22610
# 4  0500000US01009                                    56692
#
#    Percent!!SEX AND AGE!!Total population  Estimate!!SEX AND AGE!!Male  \
# 0                                   53155                        25780
# 1                                  175791                        85902
# 2                                   27699                        14652
# 3                                   22610                        12162
# 4                                   56692                        28080
#
#    Percent!!SEX AND AGE!!Male  Estimate!!SEX AND AGE!!Female  \
# 0                        48.5                          27375
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'Estimate!!SEX AND AGE!!Total population',
#  'Percent!!SEX AND AGE!!Total population',
#  'Estimate!!SEX AND AGE!!Male',
#  'Percent!!SEX AND AGE!!Male',
#  'Estimate!!SEX AND AGE!!Female',
#  'Percent!!SEX AND AGE!!Female',
#  'Estimate!!SEX AND AGE!!Under 5 years',
#  'Percent!!SEX AND AGE!!Under 5 years',
#  'Estimate!!SEX AND AGE!!5 to 9 years',
#  'Percent!!SEX AND AGE!!5 to 9 years',
#  'Estimate!!SEX AND AGE!!10 to 14 years',
#  'Percent!!SEX AND AGE!!10 to 14 years',
#  'Estimate!!SEX AND AGE!!15 to 19 years',
#  'Percent!!SEX AND AGE!!15 to 19 years',
#  'Estimate!!SEX AND AGE!!20 to 24 years',
#  'Percent!!SEX AND AGE!!20 to 24 years',
#  'Estimate!!SEX AND AGE!!25 to 34 years',
#  'Percent!!SEX AND AGE!!25 to 34 years',
#  'Estimate!!SEX AND AGE!!35 to 44 years',
#  'Percent!!SEX AND AGE!!35 to 44 years',
#  'Estimate!!SEX AND AGE!!45 to 54 years',
#  'Percent!!SEX AND AGE!!45 to 54 years',
#  'Estimate!!SEX AND AGE!!55 to 59 years',
# ...

# %%
df = df.rename(columns = {'Estimate!!SEX AND AGE!!Median age (years)' : 'median_age'})

# %%
total_pop_col = df[["Estimate!!SEX AND AGE!!Total population", "id"]]
df = df[df.columns.drop(list(df.filter(regex='Estimate')))]
df = df[df.columns.drop(list(df.filter(regex='Percent!!SEX AND AGE!!Total population')))]
df = df[df.columns.drop(list(df.filter(regex='RACE!!Two or more races!!')))]
df = df[df.columns.drop(list(df.filter(regex='RACE!!One race!!')))]
df = pd.merge(df, total_pop_col, how="left", on="id")
df.head(5)
# Out:
#                id  Percent!!SEX AND AGE!!Male  Percent!!SEX AND AGE!!Female  \
# 0  0500000US01001                        48.5                          51.5
# 1  0500000US01003                        48.9                          51.1
# 2  0500000US01005                        52.9                          47.1
# 3  0500000US01007                        53.8                          46.2
# 4  0500000US01009                        49.5                          50.5
#
#    Percent!!SEX AND AGE!!Under 5 years  Percent!!SEX AND AGE!!5 to 9 years  \
# 0                                  6.6                                 7.4
# 1                                  6.2                                 6.5
# 2                                  6.3                                 5.5
# 3                                  6.1                                 6.6
# 4                                  6.4                                 6.5
#
# ...

# %%
df.columns = df.columns.str.replace('Estimate!!SEX AND AGE!!Total population', 'total_pop')
df.columns = df.columns.str.replace('Percent!!', 'pct_')
df.columns = df.columns.str.replace('SEX AND AGE!!', 'sex_age_')
df.columns = df.columns.str.replace('HISPANIC OR LATINO AND RACE!!', 'ethnicity_')
df.columns = df.columns.str.replace('RACE!!', 'race_')
df.columns = df.columns.str.replace('Male', 'male')
df.columns = df.columns.str.replace('Female', 'female')
df.columns = df.columns.str.replace('CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!', 'voting_age_citizen_')
df.columns = df.columns.str.replace('Race alone or in combination with one or more other races', 'one_or_more_race')
df.head(5)
# Out:
#                id  pct_sex_age_male  pct_sex_age_female  \
# 0  0500000US01001              48.5                51.5
# 1  0500000US01003              48.9                51.1
# 2  0500000US01005              52.9                47.1
# 3  0500000US01007              53.8                46.2
# 4  0500000US01009              49.5                50.5
#
#    pct_sex_age_Under 5 years  pct_sex_age_5 to 9 years  \
# 0                        6.6                       7.4
# 1                        6.2                       6.5
# 2                        6.3                       5.5
# 3                        6.1                       6.6
# 4                        6.4                       6.5
#
#    pct_sex_age_10 to 14 years  pct_sex_age_15 to 19 years  \
# 0                         8.1                         8.6
# 1                         6.6                         6.4
# 2                         6.6                         6.9
# ...

# %%
df = df.drop(columns=["pct_sex_age_Median age (years)"])
df.columns = df.columns.str.replace('Under 5 years', 'under_5')
df.columns = df.columns.str.replace('5 to 9 years', '5_to_9')
df.columns = df.columns.str.replace('10 to 14 years', '10_to_14')
df.columns = df.columns.str.replace('15 to 19 years', '15_to_19')
df.columns = df.columns.str.replace('20 to 24 years', '20_to_24')
df.columns = df.columns.str.replace('25 to 34 years', '25_to_34')
df.columns = df.columns.str.replace('35 to 44 years', '35_to_44')
df.columns = df.columns.str.replace('45 to 54 years', '45_to_54')
df.columns = df.columns.str.replace('55 to 59 years', '55_to_59')
df.columns = df.columns.str.replace('60 to 64 years', '60_to_64')
df.columns = df.columns.str.replace('65 to 74 years', '65_to_74')
df.columns = df.columns.str.replace('75 to 84 years', '75_to_84')
df.columns = df.columns.str.replace(' years and over', '+')
df.columns = df.columns.str.replace('!!male', '_male')
df.columns = df.columns.str.replace('!!female', '_female')


list(df.columns)
# Out:
# ['id',
#  'pct_sex_age_male',
#  'pct_sex_age_female',
#  'pct_sex_age_under_5',
#  'pct_sex_age_5_to_9',
#  'pct_sex_age_10_to_14',
#  'pct_sex_age_15_to_19',
#  'pct_sex_age_20_to_24',
#  'pct_sex_age_25_to_34',
#  'pct_sex_age_35_to_44',
#  'pct_sex_age_45_to_54',
#  'pct_sex_age_55_to_59',
#  'pct_sex_age_60_to_64',
#  'pct_sex_age_65_to_74',
#  'pct_sex_age_75_to_84',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_sex_age_18+.1',
#  'pct_sex_age_male.1',
#  'pct_sex_age_female.1',
#  'pct_sex_age_65+.1',
#  'pct_sex_age_male.2',
#  'pct_sex_age_female.2',
#  'pct_race_Total population',
#  'pct_race_One race',
#  'pct_race_Two or more races',
#  'pct_race_One race.1',
#  'pct_race_Two or more races.1',
#  'pct_race_one_or_more_race!!Total population',
#  'pct_race_White',
#  'pct_race_Black or African American',
#  'pct_race_American Indian and Alaska Native',
#  'pct_race_Asian',
# ...

# %%
df = df.drop(columns = ["pct_sex_age_65+.1"])
df = df.drop(columns = ["pct_sex_age_18+.1"])
# df = df.drop(columns=["pct_race_Total population!!One race"])
# df = df.drop(columns=["pct_race_Total population!!Two or more races"])
df = df.drop(columns=["pct_race_One race"])
df = df.drop(columns=["pct_race_Total population"])
df = df.drop(columns=["pct_race_Two or more races"])
df = df.drop(columns=["pct_ethnicity_Total population"])
df.columns = df.columns.str.replace('!!Total population', '')
df.columns = df.columns.str.replace('!!Total population', '')
df.columns = df.columns.str.replace('Total population', '')
df.columns = df.columns.str.replace('!!Hispanic or Latino (of any race)!!', 'hispanic_')
df.columns = df.columns.str.replace('!!Not Hispanic or Latino!!', 'not_hispanic_')


list(df.columns)
# Out:
# C:\Users\philb\AppData\Local\Temp\ipykernel_3616\2788399953.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('!!Hispanic or Latino (of any race)!!', 'hispanic_')
# ['id',
#  'pct_sex_age_male',
#  'pct_sex_age_female',
#  'pct_sex_age_under_5',
#  'pct_sex_age_5_to_9',
#  'pct_sex_age_10_to_14',
#  'pct_sex_age_15_to_19',
#  'pct_sex_age_20_to_24',
#  'pct_sex_age_25_to_34',
#  'pct_sex_age_35_to_44',
#  'pct_sex_age_45_to_54',
#  'pct_sex_age_55_to_59',
#  'pct_sex_age_60_to_64',
#  'pct_sex_age_65_to_74',
#  'pct_sex_age_75_to_84',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_sex_age_male.1',
#  'pct_sex_age_female.1',
#  'pct_sex_age_male.2',
#  'pct_sex_age_female.2',
#  'pct_race_One race.1',
#  'pct_race_Two or more races.1',
#  'pct_race_one_or_more_race',
#  'pct_race_White',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='^pct_ethnicity_not_hispanic')))]
df = df[df.columns.drop(list(df.filter(regex='^pct_ethnicity_!!Hispanic or Latino (of any race)!!')))]
df = df[df.columns.drop(list(df.filter(regex='^pct_voting_age')))]

df = df.drop(columns=["pct_ethnicity_Hispanic or Latino (of any race)!!Mexican"])
df = df.drop(columns=["pct_ethnicity_Hispanic or Latino (of any race)!!Puerto Rican"])
df = df.drop(columns=["pct_ethnicity_Hispanic or Latino (of any race)!!Cuban"])
df = df.drop(columns=["pct_ethnicity_Hispanic or Latino (of any race)!!Other Hispanic or Latino"])
df = df.drop(columns=["pct_ethnicity_Not Hispanic or Latino"])
df = df.drop(columns=["pct_Total housing units"])
# df = df.drop(columns=["pct_CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population"])

df.columns = df.columns.str.replace('White', 'white')
df.columns = df.columns.str.replace('Black or African American', 'black')

df.columns = df.columns.str.replace('American Indian and Alaska Native', 'native_american')
df.columns = df.columns.str.replace('Asian', 'asian')
df.columns = df.columns.str.replace('Native Hawaiian and Other Pacific Islander', 'native_hawaiian_pacific_islander')
df.columns = df.columns.str.replace('Some other race', 'other_race')
df = df.rename(columns = {"pct_ethnicity_Hispanic or Latino (of any race)":"pct_ethnicity_hispanic"})
df.columns = df.columns.str.replace('!!', '_')
df.columns = df.columns.str.replace('pct_race', 'pct')


list(df.columns)
# Out:
# ['id',
#  'pct_sex_age_male',
#  'pct_sex_age_female',
#  'pct_sex_age_under_5',
#  'pct_sex_age_5_to_9',
#  'pct_sex_age_10_to_14',
#  'pct_sex_age_15_to_19',
#  'pct_sex_age_20_to_24',
#  'pct_sex_age_25_to_34',
#  'pct_sex_age_35_to_44',
#  'pct_sex_age_45_to_54',
#  'pct_sex_age_55_to_59',
#  'pct_sex_age_60_to_64',
#  'pct_sex_age_65_to_74',
#  'pct_sex_age_75_to_84',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_sex_age_male.1',
#  'pct_sex_age_female.1',
#  'pct_sex_age_male.2',
#  'pct_sex_age_female.2',
#  'pct_One race.1',
#  'pct_Two or more races.1',
#  'pct_one_or_more_race',
#  'pct_white',
#  'pct_black',
#  'pct_native_american',
#  'pct_asian',
#  'pct_native_hawaiian_pacific_islander',
#  'pct_other_race',
#  'pct_ethnicity_hispanic',
#  'pct_ethnicity_Not Hispanic or Latino_white alone',
#  'pct_ethnicity_Not Hispanic or Latino_black alone',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='.[1-9]$')))]

df = df[df.columns.drop(['pct_ethnicity_Not Hispanic or Latino_white alone',
 'pct_ethnicity_Not Hispanic or Latino_black alone',
 'pct_ethnicity_Not Hispanic or Latino_native_american alone',
 'pct_ethnicity_Not Hispanic or Latino_asian alone',
 'pct_ethnicity_Not Hispanic or Latino_native_hawaiian_pacific_islander alone',
 'pct_ethnicity_Not Hispanic or Latino_other_race alone',
 'pct_ethnicity_Not Hispanic or Latino_Two or more races',
 'pct_ethnicity_Not Hispanic or Latino_Two or more races_Two races including other_race',
 'pct_ethnicity_Not Hispanic or Latino_Two or more races_Two races excluding other_race, and Three or more races'])]

list(df.columns)
# Out:
# ['id',
#  'pct_sex_age_male',
#  'pct_sex_age_female',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_one_or_more_race',
#  'pct_white',
#  'pct_black',
#  'pct_native_american',
#  'pct_asian',
#  'pct_native_hawaiian_pacific_islander',
#  'pct_other_race',
#  'pct_ethnicity_hispanic',
#  'Geographic Area Name',
#  'year',
#  'total_pop']

# %%
df.head()
# Out:
#                id  pct_sex_age_male  pct_sex_age_female  pct_sex_age_85+  \
# 0  0500000US01001              48.5                51.5              1.1
# 1  0500000US01003              48.9                51.1              1.6
# 2  0500000US01005              52.9                47.1              1.8
# 3  0500000US01007              53.8                46.2              0.7
# 4  0500000US01009              49.5                50.5              1.2
#
#    median_age  pct_sex_age_18+  pct_sex_age_21+  pct_sex_age_62+  \
# 0        36.2             72.3             67.9             14.3
# 1        41.0             76.7             73.3             20.1
# 2        38.0             77.5             73.7             16.7
# 3        38.3             76.6             72.5             15.7
# 4        38.3             75.2             71.3             18.1
#
#    pct_sex_age_65+  pct_one_or_more_race  pct_white  pct_black  \
# 0             11.4                 53155       80.4       18.2
# ...

# %%
df['fips'] = df['id'].str[-5:]
df.head(5)
# Out:
#                id  pct_sex_age_male  pct_sex_age_female  pct_sex_age_85+  \
# 0  0500000US01001              48.5                51.5              1.1
# 1  0500000US01003              48.9                51.1              1.6
# 2  0500000US01005              52.9                47.1              1.8
# 3  0500000US01007              53.8                46.2              0.7
# 4  0500000US01009              49.5                50.5              1.2
#
#    median_age  pct_sex_age_18+  pct_sex_age_21+  pct_sex_age_62+  \
# 0        36.2             72.3             67.9             14.3
# 1        41.0             76.7             73.3             20.1
# 2        38.0             77.5             73.7             16.7
# 3        38.3             76.6             72.5             15.7
# 4        38.3             75.2             71.3             18.1
#
#    pct_sex_age_65+  pct_one_or_more_race  ...  pct_black  pct_native_american  \
# ...

# %%
df.to_csv("..\Data\Clean\ACS\ACSDP052010_clean.csv")
