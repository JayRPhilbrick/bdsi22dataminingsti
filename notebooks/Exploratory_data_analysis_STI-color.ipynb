# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../Data/Intermediate/CDCSTDoverall2000_2020_processed.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  year   fips  cases_chlamydia  \
# 0           0  2000  45001             61.0
# 1           1  2000  22001              0.0
# 2           2  2000  51001            153.0
# 3           3  2000  16001            644.0
# 4           4  2000  19001              8.0
#
#    cases_early_non-primary_non-secondary_syphilis  cases_gonorrhea  \
# 0                                             1.0             57.0
# 1                                             8.0              0.0
# 2                                             2.0             88.0
# 3                                             0.0             33.0
# 4                                             0.0              0.0
#
#    cases_primary_and_secondary_syphilis  rate_per_100000_chlamydia  \
# 0                                   2.0                      232.6
# 1                                  11.0                        0.0
# 2                                   0.0                      398.7
# 3                                   1.0                      212.3
# 4                                   0.0                       97.6
#
#    rate_per_100000_early_non-primary_non-secondary_syphilis  \
# 0                                                3.8
# 1                                               13.6
# 2                                                5.2
# 3                                                0.0
# 4                                                0.0
#
#    rate_per_100000_gonorrhea  ...  rate_per_100000_male_gonorrhea_multiracial  \
# 0                      217.4  ...                                         NaN
# 1                        0.0  ...                                         NaN
# 2                      229.3  ...                                         NaN
# 3                       10.9  ...                                         NaN
# 4                        0.0  ...                                         NaN
#
#    rate_per_100000_male_gonorrhea_native_hawaiian_other_pacific_islander  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_gonorrhea_white  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_american_indian_alaska_native  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_asian  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_black_african_american  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_hispanic_latino  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_multiracial  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_native_hawaiian_other_pacific_islander  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    rate_per_100000_male_primary_and_secondary_syphilis_white
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 131 columns]

# %%
df_sum = data.groupby(['year'])['cases_gonorrhea','cases_chlamydia','cases_early_non-primary_non-secondary_syphilis','cases_primary_and_secondary_syphilis'].sum().reset_index()
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/3700150800.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_sum = data.groupby(['year'])['cases_gonorrhea','cases_chlamydia','cases_early_non-primary_non-secondary_syphilis','cases_primary_and_secondary_syphilis'].sum().reset_index()

# %%
df_sum
# Out:
#     year  cases_gonorrhea  cases_chlamydia  \
# 0   2000         211146.0         382937.0
# 1   2001         245376.0         487710.0
# 2   2002         345771.0         813734.0
# 3   2003         332157.0         869687.0
# 4   2004         327207.0         921261.0
# 5   2005         336097.0         964913.0
# 6   2006         356037.0        1027346.0
# 7   2007         353727.0        1107441.0
# 8   2008         331487.0        1199261.0
# 9   2009         299468.0        1243433.0
# 10  2010         308238.0        1307386.0
# 11  2011         320177.0        1408438.0
# 12  2012         333797.0        1422567.0
# 13  2013         328707.0        1387626.0
# 14  2014         346942.0        1433505.0
# 15  2015         387699.0        1496914.0
# 16  2016         461759.0        1581698.0
# 17  2017         553590.0        1703383.0
# 18  2018         580700.0        1754481.0
# 19  2019         613958.0        1801298.0
# 20  2020         676681.0        1578170.0
#
#     cases_early_non-primary_non-secondary_syphilis  \
# 0                                           9989.0
# 1                                           9262.0
# 2                                           9064.0
# 3                                           8989.0
# 4                                           8101.0
# 5                                           8586.0
# 6                                           9534.0
# 7                                          11154.0
# 8                                          12601.0
# 9                                          13220.0
# 10                                         13779.0
# 11                                         13328.0
# 12                                         14722.0
# 13                                         17178.0
# 14                                         19655.0
# 15                                         24431.0
# 16                                         29063.0
# 17                                         34502.0
# 18                                         39074.0
# 19                                         42026.0
# 20                                         43404.0
#
#     cases_primary_and_secondary_syphilis
# 0                                 6117.0
# 1                                 6287.0
# 2                                 7089.0
# 3                                 7352.0
# 4                                 8152.0
# 5                                 8935.0
# 6                                 9895.0
# 7                                11620.0
# 8                                13639.0
# 9                                14216.0
# 10                               13989.0
# 11                               14216.0
# 12                               15965.0
# 13                               17746.0
# 14                               20328.0
# 15                               24219.0
# 16                               28090.0
# 17                               31016.0
# 18                               35385.0
# 19                               39217.0
# 20                               41880.0

# %% [markdown]
# ### Cases with change in time nationally

# %%
plt.figure(figsize = (15,8))
g = sns.lineplot(data = df_sum, x = 'year', y = 'cases_chlamydia',marker = "o")
sns.lineplot(data = df_sum, x = 'year', y = 'cases_gonorrhea',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('cases')
g.set_xticks(df_sum['year'])
g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_chlamydia_gonorrhea.png',dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [172], in <cell line: 8>()
#       6 g.set_ylabel('cases')
#       7 g.set_xticks(df_sum['year'])
# ----> 8 g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
#       9 plt.legend(labels=["Chlamydia","Gonorrhea"])
#      10 plt.savefig('../Output/EDA/cases_chlamydia_gonorrhea.png',dpi=300)
#
# NameError: name 'ax' is not defined

# %%
plt.figure(figsize = (15,8))
g = sns.lineplot(data = df_sum, x = 'year', y = 'cases_early_non-primary_non-secondary_syphilis',marker = "<")
sns.lineplot(data = df_sum, x = 'year', y = 'cases_primary_and_secondary_syphilis', marker = "o")
g.set_ylabel('cases')
g.set_xticks(df_sum['year'])
g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
plt.legend(labels=["Early Non-Primary, Non-Secondary Syphilis","Primary and Secondary Syphilis"])
plt.savefig('../Output/EDA/cases_syphilis.png',dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [174], in <cell line: 6>()
#       4 g.set_ylabel('cases')
#       5 g.set_xticks(df_sum['year'])
# ----> 6 g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
#       7 plt.legend(labels=["Early Non-Primary, Non-Secondary Syphilis","Primary and Secondary Syphilis"])
#       8 plt.savefig('../Output/EDA/cases_syphilis.png',dpi=300)
#
# NameError: name 'ax' is not defined

# %% [markdown]
# ### Cases over race

# %%
tot_df = []
for j,i in enumerate(np.arange(2016, 2021, 1)):
    tot_df.append(pd.read_csv('../Data/Raw/CDC/CDCSTDcountysexrace'+ 
                              str(i) +'.csv', sep = ',', skiprows = 4))
df = pd.concat(tot_df, axis = 0)

# %%
df.head()
# Out:
#                         Indicator  Year             Geography   FIPS  \
# 0  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 1  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 2  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 3  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 4  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
#
#                            Race/Ethnicity     Sex               Cases  \
# 0                                   White    Male  Data not available
# 1                                   White  Female  Data not available
# 2                                 Unknown    Male  Data not available
# 3                                 Unknown  Female  Data not available
# 4  Native Hawaiian/Other Pacific Islander    Male  Data not available
#
#       Rate per 100000
# 0  Data not available
# 1  Data not available
# 2  Data not available
# 3  Data not available
# 4  Data not available

# %%
df.loc[df["Year"].str.startswith('2020',na=False), "Year"] = "2020"

# %%
data_to_be_removed = ["Cases"]

# %%
for col in data_to_be_removed:
    df.loc[df[col].str.contains("Data",na = False), col] = np.nan
    df[col] = df[col].str.replace(',','')
df[['Cases','Year']] = df[['Cases','Year']].apply(pd.to_numeric)

# %%
searchfor = ['Gonorrhea', 'Chlamydia']
df_refine = df[df.Indicator.str.contains('|'.join(searchfor))]

# %%
df_race = df_refine.groupby(['Year','Race/Ethnicity','Indicator'])['Cases'].sum().reset_index()
df_race.head()
# Out:
#    Year                 Race/Ethnicity  Indicator  Cases
# 0  2016  American Indian/Alaska Native  Chlamydia    0.0
# 1  2016  American Indian/Alaska Native  Gonorrhea    0.0
# 2  2016                          Asian  Chlamydia    0.0
# 3  2016                          Asian  Gonorrhea    0.0
# 4  2016         Black/African American  Chlamydia    0.0

# %%
df_race = df_race[df_race.Year.isin([2019,2020])]

# %%
plt.figure(figsize = (15,8))
g = sns.barplot(data = df_race[df_race.Indicator == 'Chlamydia'], x = 'Year', y = 'Cases',hue = 'Race/Ethnicity')
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
# g.set_xticks(pd.unique(df_race['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_race_chlamydia.png',dpi=300)
plt.title("Cases for Chlamydia")
plt.show()

# %%
plt.figure(figsize = (15,8))
g = sns.barplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',hue = 'Race/Ethnicity')
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
# g.set_xticks(pd.unique(df_race['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_race_gonorrhea.png',dpi=300)
plt.title("Cases for Gonorrhea")
plt.show()

# %% [markdown]
# ### Cases over Sex

# %%
tot_df = []
for j,i in enumerate(np.arange(2016, 2021, 1)):
    tot_df.append(pd.read_csv('../Data/Raw/CDC/CDCSTDcountysexrace'+ 
                              str(i) +'.csv', sep = ',', skiprows = 4))
df = pd.concat(tot_df, axis = 0)

# %%
df.head()
# Out:
#                         Indicator  Year             Geography   FIPS  \
# 0  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 1  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 2  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 3  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
# 4  Primary and Secondary Syphilis  2016  Abbeville County, SC  45001
#
#                            Race/Ethnicity     Sex               Cases  \
# 0                                   White    Male  Data not available
# 1                                   White  Female  Data not available
# 2                                 Unknown    Male  Data not available
# 3                                 Unknown  Female  Data not available
# 4  Native Hawaiian/Other Pacific Islander    Male  Data not available
#
#       Rate per 100000
# 0  Data not available
# 1  Data not available
# 2  Data not available
# 3  Data not available
# 4  Data not available

# %%
df.loc[df["Year"].str.startswith('2020',na=False), "Year"] = "2020"

# %%
data_to_be_removed = ["Cases"]

# %%
for col in data_to_be_removed:
    df.loc[df[col].str.contains("Data",na = False), col] = np.nan
    df[col] = df[col].str.replace(',','')
df[['Cases','Year']] = df[['Cases','Year']].apply(pd.to_numeric)

# %%
searchfor = ['Gonorrhea', 'Chlamydia']
df_refine = df[df.Indicator.str.contains('|'.join(searchfor))]

# %%
df_race = df_refine.groupby(['Year','Sex','Indicator'])['Cases'].sum().reset_index()
df_race.head()
# Out:
#    Year     Sex  Indicator  Cases
# 0  2016  Female  Chlamydia    0.0
# 1  2016  Female  Gonorrhea    0.0
# 2  2016    Male  Chlamydia    0.0
# 3  2016    Male  Gonorrhea    0.0
# 4  2017  Female  Chlamydia    0.0

# %%
df_race = df_race[df_race.Year.isin([2019,2020])]

# %%
plt.figure(figsize = (15,8))
g = sns.barplot(data = df_race[df_race.Indicator == 'Chlamydia'], x = 'Year', y = 'Cases',hue = 'Sex')
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
# g.set_xticks(pd.unique(df_race['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_sex_chlamydia.png',dpi=300)
plt.title("Cases for Chlamydia")
plt.show()

# %%
plt.figure(figsize = (15,8))
g = sns.barplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',hue = 'Sex')
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
# g.set_xticks(pd.unique(df_race['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_sex_gonorrhea.png',dpi=300)
plt.title("Cases for Gonorrhea")
plt.show()

# %% [markdown]
# ### HIV dataset

# %%
df = pd.read_csv("../Data/Raw/CDC/HIV/CDCHIVcountyracesex2017_2020.csv",skiprows=11)
print(data.shape)
df.head()
# Out:
# (67586, 131)
#                      Indicator                      Year  \
# 0  Receipt of HIV medical care  2020 (COVID-19 Pandemic)
# 1  Receipt of HIV medical care  2020 (COVID-19 Pandemic)
# 2  Receipt of HIV medical care                      2019
# 3  Receipt of HIV medical care                      2019
# 4  Receipt of HIV medical care                      2018
#
#               Geography   FIPS     Sex               Cases Rate per 100000  \
# 0  Abbeville County, SC  45001    Male                  39             NaN
# 1  Abbeville County, SC  45001  Female                   7             NaN
# 2  Abbeville County, SC  45001    Male                  35             NaN
# 3  Abbeville County, SC  45001  Female                  10             NaN
# 4  Abbeville County, SC  45001    Male  Data not available             NaN
#
#               Percent
# 0                92.9
# 1                63.6
# 2                87.5
# 3                83.3
# 4  Data not available

# %%
df.loc[df["Year"].str.startswith('2020',na=False), "Year"] = "2020"

# %%
data_to_be_removed = ["Cases","Percent","Rate per 100000"]

# %%
for col in data_to_be_removed:
    df.loc[df[col].str.contains("Data",na = False), col] = np.nan
    df[col] = df[col].str.replace(',','')
df[['Cases','Year']] = df[['Cases','Year']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#                      Indicator  Year             Geography   FIPS     Sex  \
# 0  Receipt of HIV medical care  2020  Abbeville County, SC  45001    Male
# 1  Receipt of HIV medical care  2020  Abbeville County, SC  45001  Female
# 2  Receipt of HIV medical care  2019  Abbeville County, SC  45001    Male
# 3  Receipt of HIV medical care  2019  Abbeville County, SC  45001  Female
# 4  Receipt of HIV medical care  2018  Abbeville County, SC  45001    Male
#
#    Cases Rate per 100000 Percent
# 0   39.0             NaN    92.9
# 1    7.0             NaN    63.6
# 2   35.0             NaN    87.5
# 3   10.0             NaN    83.3
# 4    NaN             NaN     NaN

# %%
df_hiv = df.groupby(['Year','Indicator'])['Cases'].sum().reset_index()
df_hiv.head()
# Out:
#    Year                                       Indicator     Cases
# 0  2017                                   HIV diagnoses   31452.0
# 1  2017                                  HIV prevalence  946544.0
# 2  2017                           HIV viral suppression  293738.0
# 3  2017                             Linkage to HIV care   13620.0
# 4  2017  PrEP coverage and number of persons prescribed   96755.0

# %%
plt.figure(figsize = (15,8))
g = sns.barplot(data = df_hiv, x = 'Year', y = 'Cases',hue = 'Indicator')
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
# g.set_xticks(pd.unique(df_race['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
plt.savefig('../Output/EDA/cases_hiv.png',dpi=300)
# plt.title("Cases for Chlamydia")
plt.show()

# %%
df_hiv_refine = df_hiv[df_hiv.Indicator == 'HIV diagnoses']

# %%
df_hiv_refine
# Out:
#     Year      Indicator    Cases
# 0   2017  HIV diagnoses  31452.0
# 6   2018  HIV diagnoses  30776.0
# 12  2019  HIV diagnoses  29984.0
# 18  2020  HIV diagnoses  24250.0

# %%
plt.figure(figsize = (15,8))
g = sns.lineplot(data = df_hiv_refine, x = 'Year', y = 'Cases',marker = "o")
# sns.lineplot(data = df_race[df_race.Indicator == 'Gonorrhea'], x = 'Year', y = 'Cases',marker = ">")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Early Non-Primary, Non-Secondary Syphilis',marker = "<")
# sns.lineplot(data = df_sum, x = 'year', y = 'cases_Primary and Secondary Syphilis', marker = "|")
g.set_ylabel('Cases')
g.set_xticks(pd.unique(df_hiv['Year']))
# g.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# plt.legend(labels=["Chlamydia","Gonorrhea"])
# plt.savefig('../Output/EDA/cases_hiv.png',dpi=300)
# plt.title("Cases for Chlamydia")
plt.show()

# %% [markdown]
# ### Counties rate per 1000000 Chlamydia

# %%
tot_df = []
for j,i in enumerate(np.arange(2019, 2021, 1)):
    tot_df.append(pd.read_csv('../Data/Raw/CDC/CDCSTDcountysexrace'+ 
                              str(i) +'.csv', sep = ',', skiprows = 4))
df = pd.concat(tot_df, axis = 0)

# %%
df.loc[df["Year"].str.startswith('2020',na=False), "Year"] = "2020"

# %%
data_to_be_removed = ["Cases","Rate per 100000"]

# %%
for col in data_to_be_removed:
    df.loc[df[col].str.contains("Data",na = False), col] = np.nan
    df[col] = df[col].str.replace(',','')
df[['Cases','Year','Rate per 100000']] = df[['Cases','Year','Rate per 100000']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#                         Indicator  Year             Geography   FIPS  \
# 0  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 1  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 2  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 3  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 4  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
#
#                            Race/Ethnicity     Sex  Cases  Rate per 100000
# 0                                   White    Male    NaN              NaN
# 1                                   White  Female    NaN              NaN
# 2                                 Unknown    Male    NaN              NaN
# 3                                 Unknown  Female    NaN              NaN
# 4  Native Hawaiian/Other Pacific Islander    Male    NaN              NaN

# %%
searchfor = ['Chlamydia']
df_refine= df[df.Indicator.str.contains('|'.join(searchfor))]

# %%
df_race = df_refine.groupby(['Year','Geography','FIPS'])['Rate per 100000','Cases'].mean().reset_index()
df_race.head()
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/2708107901.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_race = df_refine.groupby(['Year','Geography','FIPS'])['Rate per 100000','Cases'].mean().reset_index()
#    Year             Geography   FIPS  Rate per 100000      Cases
# 0  2019  Abbeville County, SC  45001       189.050000   7.812500
# 1  2019     Acadia Parish, LA  22001       463.992857  21.562500
# 2  2019   Accomack County, VA  51001       373.420000  18.666667
# 3  2019        Ada County, ID  16001              NaN        NaN
# 4  2019      Adair County, IA  19001        78.300000   2.083333

# %%
df = df_race.pivot_table(index=['Geography','FIPS'], columns=['Year']).reset_index()
# df.columns = df.columns.map('_'.join).str.strip('_')
df.head()
# Out:
#                  Geography   FIPS      Cases          Rate per 100000  \
# Year                                    2019     2020            2019
# 0     Abbeville County, SC  45001   7.812500   6.1875      189.050000
# 1        Acadia Parish, LA  22001  21.562500  30.0000      463.992857
# 2      Accomack County, VA  51001  18.666667  13.1250      373.420000
# 3         Adair County, IA  19001   2.083333      NaN       78.300000
# 4         Adair County, KY  21001   3.125000   3.0000      219.814286
#
#
# Year        2020
# 0      35.828571
# 1     515.530000
# 2     225.414286
# 3            NaN
# 4      12.537500

# %%
df['diff_rate'] = df['Rate per 100000'][2020] - df['Rate per 100000'][2019]

# %%
df.head()
# Out:
#                  Geography   FIPS      Cases          Rate per 100000  \
# Year                                    2019     2020            2019
# 0     Abbeville County, SC  45001   7.812500   6.1875      189.050000
# 1        Acadia Parish, LA  22001  21.562500  30.0000      463.992857
# 2      Accomack County, VA  51001  18.666667  13.1250      373.420000
# 3         Adair County, IA  19001   2.083333      NaN       78.300000
# 4         Adair County, KY  21001   3.125000   3.0000      219.814286
#
#                    diff_rate
# Year        2020
# 0      35.828571 -153.221429
# 1     515.530000   51.537143
# 2     225.414286 -148.005714
# 3            NaN         NaN
# 4      12.537500 -207.276786

# %%
plt.figure(figsize = (15,8))
g = sns.kdeplot(data = df,x = "diff_rate")
plt.title("Chlamydia")
plt.savefig("../Output/EDA/Chlamydia_rate_diff_kernel.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %%
df.sort_values("diff_rate")[:10]
# Out:
#                    Geography   FIPS     Cases            Rate per 100000  \
# Year                                     2019       2020            2019
# 1742    Mcdonough County, IL  17109   17.6875  12.700000     2070.350000
# 2727  Vanderburgh County, IN  18163   69.5625   0.000000     1135.392857
# 257     Brookings County, SD  46011    9.0000  11.750000     1224.442857
# 175        Benton County, OR  41003   34.1250  31.900000     1308.271429
# 269         Brown County, SD  46013    9.5625   6.875000     1083.921429
# 1665      Mahaska County, IA  19123    8.0000   6.000000     1066.420000
# 40       Allegany County, NY  36003    8.5625   0.250000      944.935714
# 1166     Hennepin County, MN  27053  522.8750  50.000000     1192.235714
# 554         Coles County, IL  17029   22.2500  23.666667     1074.964286
# 2698        Union County, KY  21225   12.1000   3.500000      882.125000
#
#                     diff_rate
# Year        2020
# 1742  372.012500 -1698.337500
# 2727    0.000000 -1135.392857
# 257   129.850000 -1094.592857
# 175   261.325000 -1046.946429
# 269    45.533333 -1038.388095
# 1665   53.862500 -1012.557500
# 40      0.000000  -944.935714
# 1166  271.000000  -921.235714
# 554   157.700000  -917.264286
# 2698    0.000000  -882.125000

# %%
df.sort_values("diff_rate",ascending= False)[:10]
# Out:
#                      Geography   FIPS     Cases             Rate per 100000  \
# Year                                       2019        2020            2019
# 2515      St. Louis County, MN  27137   62.9000   71.200000      272.550000
# 188     Bethel Census Area, AK   2050    0.0000   43.100000        0.000000
# 705        Delaware County, PA  42045  197.6000  231.166667      144.537500
# 1839     Monongalia County, WV  54061    0.0000   33.500000        0.000000
# 1756       Mclennan County, TX  48309   93.6000  167.750000      241.987500
# 1971   North Slope Borough, AK   2185    0.0000   11.000000        0.000000
# 1650        Madison County, IL  17119   71.7000   98.750000      166.512500
# 1993  Oglala Lakota County, SD  46102    0.0000   23.900000        0.000000
# 464        Chippewa County, WI  55017    9.6875   14.083333      146.978571
# 1113       Hardeman County, TN  47069    0.0000   19.500000        0.000000
#
#                     diff_rate
# Year         2020
# 2515  1042.500000  769.950000
# 188    679.475000  679.475000
# 705    695.220000  550.682500
# 1839   548.871429  548.871429
# 1756   775.120000  533.132500
# 1971   504.750000  504.750000
# 1650   618.100000  451.587500
# 1993   445.887500  445.887500
# 464    579.130000  432.151429
# 1113   424.500000  424.500000

# %%
plt.figure(figsize = (15,8))
g = sns.scatterplot(x = df_ref['rate per 100000'][2019],y = df_ref['rate per 100000'][2020],size = df_ref.total_pop[2019],hue = data_temp["color"],sizes=(10, 1000),alpha=0.5)
xpoints = ypoints = plt.xlim()

x1=0
y1=0
#col = np.where(rate20>np.tan(math.pi *3/8)*rate19, "r", "m")
s1 = np.tan(math.pi *3/8)
plt.axline((x1,y1), slope = s1)
plt.grid()


x=np.linspace(0,1000,1000)
y=s1*x

plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)
plt.plot(x, y, linestyle='--', color='k', lw=3, scalex=False, scaley=False)


s2 = np.tan(math.pi /8)
plt.axline((x1,y1), slope = s2, linestyle='--', color='k', lw=3)


#plt.plot(x,y)

#plt.scatter(x, y, c =col)
#plt.scatter(x, y>np.tan(math.pi *3/8)*x,color= 'red', label='strong')
#plt.scatter(x1, x1>y1>np.tan(math.pi /8)*x1,color= 'green', label='weak')

# sns.lineplot(x = [1,2],y =[1,2])
plt.title("Chlamydia rate per 100000")
plt.savefig("../Output/EDA/Chlamydia_scatterplot3.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %% [markdown]
# ### Counties rate per 1000000 Gonorrhea

# %%
tot_df = []
for j,i in enumerate(np.arange(2019, 2021, 1)):
    tot_df.append(pd.read_csv('../Data/Raw/CDC/CDCSTDcountysexrace'+ 
                              str(i) +'.csv', sep = ',', skiprows = 4))
df = pd.concat(tot_df, axis = 0)

# %%
df.loc[df["Year"].str.startswith('2020',na=False), "Year"] = "2020"

# %%
data_to_be_removed = ["Cases","Rate per 100000"]

# %%
for col in data_to_be_removed:
    df.loc[df[col].str.contains("Data",na = False), col] = np.nan
    df[col] = df[col].str.replace(',','')
df[['Cases','Year','Rate per 100000']] = df[['Cases','Year','Rate per 100000']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#                         Indicator  Year             Geography   FIPS  \
# 0  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 1  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 2  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 3  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
# 4  Primary and Secondary Syphilis  2019  Abbeville County, SC  45001
#
#                            Race/Ethnicity     Sex  Cases  Rate per 100000
# 0                                   White    Male    NaN              NaN
# 1                                   White  Female    NaN              NaN
# 2                                 Unknown    Male    NaN              NaN
# 3                                 Unknown  Female    NaN              NaN
# 4  Native Hawaiian/Other Pacific Islander    Male    NaN              NaN

# %%
searchfor = ['Gonorrhea']
df_refine2 = df[df.Indicator.str.contains('|'.join(searchfor))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [248], in <cell line: 2>()
#       1 searchfor = ['Gonorrhea']
# ----> 2 df_refine2 = df[df.Indicator.str.contains('|'.join(searchfor))]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Indicator'

# %%
df_race = df_refine.groupby(['Year','FIPS'])['Rate per 100000','Cases'].mean().reset_index()
df_race.head()
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/139344804.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_race = df_refine.groupby(['Year','FIPS'])['Rate per 100000','Cases'].mean().reset_index()
#    Year  FIPS  Rate per 100000    Cases
# 0  2019  1001        82.392857   7.9375
# 1  2019  1003        16.285714  14.3750
# 2  2019  1005       230.435714   8.5000
# 3  2019  1007        36.364286   3.5625
# 4  2019  1009       124.871429   5.4375

# %%
df = df_race.pivot_table(index=['FIPS'], columns=['Year']).reset_index()
# df.columns = df.columns.map('_'.join).str.strip('_')
df.head()
# Out:
#       FIPS    Cases            Rate per 100000
# Year           2019       2020            2019        2020
# 0     1001   7.9375   6.400000       82.392857   16.400000
# 1     1003  14.3750  16.562500       16.285714   37.278571
# 2     1005   8.5000   0.400000      230.435714    6.960000
# 3     1007   3.5625   6.666667       36.364286  133.320000
# 4     1009   5.4375   0.300000      124.871429   10.170000

# %%
df['diff_rate'] = df['Rate per 100000'][2020] -df['Rate per 100000'][2019]

# %%
df.head()
# Out:
#       FIPS    Cases            Rate per 100000               diff_rate
# Year           2019       2020            2019        2020
# 0     1001   7.9375   6.400000       82.392857   16.400000  -65.992857
# 1     1003  14.3750  16.562500       16.285714   37.278571   20.992857
# 2     1005   8.5000   0.400000      230.435714    6.960000 -223.475714
# 3     1007   3.5625   6.666667       36.364286  133.320000   96.955714
# 4     1009   5.4375   0.300000      124.871429   10.170000 -114.701429

# %%
plt.figure(figsize = (15,8))
g = sns.kdeplot(data = df,x = "diff_rate")
plt.title("Gonorrhea")
plt.savefig("../Output/EDA/Gonorrhea_rate_diff_kernel.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %% [markdown]
# ### Scatterplot of Chlamydia

# %%
data_pop = pd.read_csv("../Data/Intermediate/ACSDP05_merge.csv")
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/2360043603.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_pop = pd.read_csv("../Data/Intermediate/ACSDP05_merge.csv")

# %%
data_pop.head()
# Out:
#    Unnamed: 0  pct_sex_age_male  pct_sex_age_female  pct_sex_age_85+  \
# 0           0              48.5                51.5              1.1
# 1           1              48.9                51.1              1.6
# 2           2              52.9                47.1              1.8
# 3           3              53.8                46.2              0.7
# 4           4              49.5                50.5              1.2
#
#   median_age  pct_sex_age_18+  pct_sex_age_21+  pct_sex_age_62+  \
# 0       36.2             72.3             67.9             14.3
# 1       41.0             76.7             73.3             20.1
# 2       38.0             77.5             73.7             16.7
# 3       38.3             76.6             72.5             15.7
# 4       38.3             75.2             71.3             18.1
#
#    pct_sex_age_65+  pct_one_or_more_race  ...  pct_sex_age_18+_female  \
# 0             11.4                 53155  ...                     NaN
# 1             16.5                175791  ...                     NaN
# 2             13.7                 27699  ...                     NaN
# 3             12.4                 22610  ...                     NaN
# 4             14.2                 56692  ...                     NaN
#
#    pct_sex_age_65+_male  pct_sex_age_65+_female  pct_one_or_more_race_white  \
# 0                   NaN                     NaN                         NaN
# 1                   NaN                     NaN                         NaN
# 2                   NaN                     NaN                         NaN
# 3                   NaN                     NaN                         NaN
# 4                   NaN                     NaN                         NaN
#
#    pct_one_or_more_race_black  pct_one_or_more_race_native_american  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    pct_one_or_more_race_asian  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
#
#    pct_one_or_more_race_native_hawaiian_pacific_islander  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    pct_one_or_more_race_other_race  pct_sex_age_16+
# 0                              NaN              NaN
# 1                              NaN              NaN
# 2                              NaN              NaN
# 3                              NaN              NaN
# 4                              NaN              NaN
#
# [5 rows x 43 columns]

# %%
data_pop = data_pop[['year','fips','total_pop']]

# %%
data_pop = data_pop.loc[data_pop.year.isin([2019,2020]),]

# %%
data_pop
# Out:
#        year   fips  total_pop
# 28984  2019   1001      55380
# 28985  2019   1003     212830
# 28986  2019   1005      25361
# 28987  2019   1007      22493
# 28988  2019   1009      57681
# ...     ...    ...        ...
# 35420  2020  72145      51089
# 35421  2020  72147       8508
# 35422  2020  72149      21899
# 35423  2020  72151      32867
# 35424  2020  72153      34501
#
# [6441 rows x 3 columns]

# %%
df_race.columns = df_race.columns.str.lower()
df_race
# Out:
#       year   fips  rate per 100000    cases
# 0     2019   1001        82.392857   7.9375
# 1     2019   1003        16.285714  14.3750
# 2     2019   1005       230.435714   8.5000
# 3     2019   1007        36.364286   3.5625
# 4     2019   1009       124.871429   5.4375
# ...    ...    ...              ...      ...
# 6441  2020  72145              NaN      NaN
# 6442  2020  72147              NaN      NaN
# 6443  2020  72149              NaN      NaN
# 6444  2020  72151              NaN      NaN
# 6445  2020  72153              NaN      NaN
#
# [6446 rows x 4 columns]

# %%
df = pd.merge(df_race,data_pop,on = ['year','fips'])

# %%
df['adj_cases'] = df['cases']/df['total_pop']

# %%
df
# Out:
#       year   fips  rate per 100000    cases  total_pop  adj_cases
# 0     2019   1001        82.392857   7.9375      55380   0.000143
# 1     2019   1003        16.285714  14.3750     212830   0.000068
# 2     2019   1005       230.435714   8.5000      25361   0.000335
# 3     2019   1007        36.364286   3.5625      22493   0.000158
# 4     2019   1009       124.871429   5.4375      57681   0.000094
# ...    ...    ...              ...      ...        ...        ...
# 6432  2020  72145              NaN      NaN      51089        NaN
# 6433  2020  72147              NaN      NaN       8508        NaN
# 6434  2020  72149              NaN      NaN      21899        NaN
# 6435  2020  72151              NaN      NaN      32867        NaN
# 6436  2020  72153              NaN      NaN      34501        NaN
#
# [6437 rows x 6 columns]

# %%
df_ref = df.pivot_table(index=['fips'], columns=['year']).reset_index()
df_ref
# Out:
#        fips adj_cases              cases            rate per 100000  \
# year             2019      2020     2019       2020            2019
# 0      1001  0.000143  0.000115   7.9375   6.400000       82.392857
# 1      1003  0.000068  0.000076  14.3750  16.562500       16.285714
# 2      1005  0.000335  0.000016   8.5000   0.400000      230.435714
# 3      1007  0.000158  0.000298   3.5625   6.666667       36.364286
# 4      1009  0.000094  0.000005   5.4375   0.300000      124.871429
# ...     ...       ...       ...      ...        ...             ...
# 3215  72145       NaN       NaN      NaN        NaN             NaN
# 3216  72147       NaN       NaN      NaN        NaN             NaN
# 3217  72149       NaN       NaN      NaN        NaN             NaN
# 3218  72151       NaN       NaN      NaN        NaN             NaN
# 3219  72153       NaN       NaN      NaN        NaN             NaN
#
#                  total_pop
# year        2020      2019      2020
# 0      16.400000   55380.0   55639.0
# 1      37.278571  212830.0  218289.0
# 2       6.960000   25361.0   25026.0
# 3     133.320000   22493.0   22374.0
# 4      10.170000   57681.0   57755.0
# ...          ...       ...       ...
# 3215         NaN   52192.0   51089.0
# 3216         NaN    8642.0    8508.0
# 3217         NaN   22403.0   21899.0
# 3218         NaN   33499.0   32867.0
# 3219         NaN   35428.0   34501.0
#
# [3220 rows x 9 columns]

# %%
df_ref['adj_cases'][2019]
# Out:
# 0       0.000143
# 1       0.000068
# 2       0.000335
# 3       0.000158
# 4       0.000094
#           ...
# 3215         NaN
# 3216         NaN
# 3217         NaN
# 3218         NaN
# 3219         NaN
# Name: 2019, Length: 3220, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import math

# %%
plt.figure(figsize = (15,8))
rate19 = df_ref['rate per 100000'][2019]
rate20 = df_ref['rate per 100000'][2020]
g = sns.scatterplot(x = rate19,y = df_ref['rate per 100000'][2020],size = rate20,sizes=(10, 1000),alpha=0.5)
xpoints = ypoints = plt.xlim()

x1=0
y1=0
#col = np.where(rate20>np.tan(math.pi *3/8)*rate19, "r", "m")
s1 = np.tan(math.pi *3/8)
plt.axline((x1,y1), slope = s1)
plt.grid()


x=np.linspace(0,1000,1000)
y=s1*x

plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)
plt.plot(x, y, linestyle='--', color='k', lw=3, scalex=False, scaley=False)


s2 = np.tan(math.pi /8)
plt.axline((x1,y1), slope = s2, linestyle='--', color='k', lw=3)


#plt.plot(x,y)

#plt.scatter(x, y, c =col)
#plt.scatter(x, y>np.tan(math.pi *3/8)*x,color= 'red', label='strong')
#plt.scatter(x1, x1>y1>np.tan(math.pi /8)*x1,color= 'green', label='weak')

# sns.lineplot(x = [1,2],y =[1,2])
plt.title("Chlamydia rate per 100000")
plt.savefig("../Output/EDA/Chlamydia_scatterplot.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %%
plt.figure(figsize = (15,8))
g = sns.scatterplot(x = df_ref['rate per 100000'][2019],y = df_ref['rate per 100000'][2020],size = df_ref.total_pop[2019],hue = data_temp["color"],sizes=(10, 1000),alpha=0.5)
xpoints = ypoints = plt.xlim()

x1=0
y1=0
#col = np.where(rate20>np.tan(math.pi *3/8)*rate19, "r", "m")
s1 = np.tan(math.pi *3/8)
plt.axline((x1,y1), slope = s1)
plt.grid()


x=np.linspace(0,1000,1000)
y=s1*x

plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)
plt.plot(x, y, linestyle='--', color='k', lw=3, scalex=False, scaley=False)


s2 = np.tan(math.pi /8)
plt.axline((x1,y1), slope = s2, linestyle='--', color='k', lw=3)


#plt.plot(x,y)

#plt.scatter(x, y, c =col)
#plt.scatter(x, y>np.tan(math.pi *3/8)*x,color= 'red', label='strong')
#plt.scatter(x1, x1>y1>np.tan(math.pi /8)*x1,color= 'green', label='weak')

# sns.lineplot(x = [1,2],y =[1,2])
plt.title("Chlamydia rate per 100000")
plt.savefig("../Output/EDA/Chlamydia_scatterplot3.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %%
data_temp = pd.DataFrame((df_ref['rate per 100000'][2019],df_ref['rate per 100000'][2020])).transpose()
data_temp["color"]="high ratio between 2020 and 2019"
data_temp["color"].iloc[data_temp[2019]>=np.tan(3*math.pi/8)*data_temp[2020]] = "low ratio between 2020 and 2019"
data_temp["color"].iloc[(data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <np.tan(3*math.pi/8)*data_temp[2020])] = "relative low ratio between 2020 and 2019"
data_temp["color"].iloc[(np.tan(math.pi/8)*data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <data_temp[2020])] = "relative high ratio between 2020 and 2019"
#data_temp["color"].iloc[(np.tan(math.pi/8)*data_temp[2020]>data_temp[2019])] = "d"

data_temp
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/1629763629.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp["color"].iloc[data_temp[2019]>=np.tan(3*math.pi/8)*data_temp[2020]] = "low ratio between 2020 and 2019"
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/1629763629.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp["color"].iloc[(data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <np.tan(3*math.pi/8)*data_temp[2020])] = "relative low ratio between 2020 and 2019"
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_70636/1629763629.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_temp["color"].iloc[(np.tan(math.pi/8)*data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <data_temp[2020])] = "relative high ratio between 2020 and 2019"
#             2019        2020                                      color
# 0      82.392857   16.400000            low ratio between 2020 and 2019
# 1      16.285714   37.278571  relative high ratio between 2020 and 2019
# 2     230.435714    6.960000            low ratio between 2020 and 2019
# 3      36.364286  133.320000           high ratio between 2020 and 2019
# 4     124.871429   10.170000            low ratio between 2020 and 2019
# ...          ...         ...                                        ...
# 3215         NaN         NaN           high ratio between 2020 and 2019
# 3216         NaN         NaN           high ratio between 2020 and 2019
# 3217         NaN         NaN           high ratio between 2020 and 2019
# 3218         NaN         NaN           high ratio between 2020 and 2019
# 3219         NaN         NaN           high ratio between 2020 and 2019
#
# [3220 rows x 3 columns]

# %%
(data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <np.tan(3*math.pi/8)*data_temp[2020])

# %%
print(col)

# %%
list(col)

# %%
x=np.linspace(0,1000,1000)
y=3*x+6
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Scatterplot of Gonorrhea

# %%
data_pop = pd.read_csv("../Data/Intermediate/ACSDP05_merge.csv")

# %%
data_pop.head()

# %%
data_pop = data_pop[['year','fips','total_pop']]

# %%
data_pop = data_pop.loc[data_pop.year.isin([2019,2020]),]

# %%
data_pop

# %%
df_race.columns = df_race.columns.str.lower()
df_race

# %%
df = pd.merge(df_race,data_pop,on = ['year','fips'])

# %%
df['adj_cases'] = df['cases']/df['total_pop']

# %%
df

# %%
df_ref = df.pivot_table(index=['fips'], columns=['year']).reset_index()
df_ref

# %%
df_ref['adj_cases'][2019]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (15,8))
g = sns.scatterplot(x = df_ref['rate per 100000'][2019],y = df_ref['rate per 100000'][2020],size = df_ref.total_pop[2019],hue = data_temp["color"], sizes=(10, 1000),alpha=0.5)
xpoints = ypoints = plt.xlim()

x1=0
y1=0
#col = np.where(rate20>np.tan(math.pi *3/8)*rate19, "r", "m")
s1 = np.tan(math.pi *3/8)
plt.axline((x1,y1), slope = s1)
plt.grid()


x=np.linspace(0,1000,1000)
y=s1*x

plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)
plt.plot(x, y, linestyle='--', color='k', lw=3, scalex=False, scaley=False)


s2 = np.tan(math.pi /8)
plt.axline((x1,y1), slope = s2, linestyle='--', color='k', lw=3)


#plt.plot(x,y)

#plt.scatter(x, y, c =col)
#plt.scatter(x, y>np.tan(math.pi *3/8)*x,color= 'red', label='strong')
#plt.scatter(x1, x1>y1>np.tan(math.pi /8)*x1,color= 'green', label='weak')

# sns.lineplot(x = [1,2],y =[1,2])
plt.title("Gonorrhea rate per 100000")
plt.savefig("../Output/EDA/Chlamydia_scatterplot3.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()

# %%
data_temp = pd.DataFrame((df_ref['rate per 100000'][2019],df_ref['rate per 100000'][2020])).transpose()
data_temp["color"]="high ratio between 2020 and 2019"
data_temp["color"].iloc[data_temp[2019]>=np.tan(3*math.pi/8)*data_temp[2020]] = "low ratio between 2020 and 2019"
data_temp["color"].iloc[(data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <np.tan(3*math.pi/8)*data_temp[2020])] = "relative low ratio between 2020 and 2019"
data_temp["color"].iloc[(np.tan(math.pi/8)*data_temp[2020]<=data_temp[2019]) & (data_temp[2019] <data_temp[2020])] = "relative high ratio between 2020 and 2019"
#data_temp["color"].iloc[(np.tan(math.pi/8)*data_temp[2020]>data_temp[2019])] = "d"

data_temp
