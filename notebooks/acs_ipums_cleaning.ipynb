# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("..\Data\Raw\ACS\ACS2000_2020.csv", nrows=10000)

# %%
df.head(20)
# Out:
#     YEAR  SAMPLE  SERIAL  CBSERIAL   HHWT        CLUSTER  STATEFIP  COUNTYFIP  \
# 0   2000  200004       1       NaN  600.0  2000000000014        17        NaN
# 1   2000  200004       1       NaN  600.0  2000000000014        17        NaN
# 2   2000  200004       2       NaN  600.0  2000000000024        48        NaN
# 3   2000  200004       2       NaN  600.0  2000000000024        48        NaN
# 4   2000  200004       2       NaN  600.0  2000000000024        48        NaN
# 5   2000  200004       2       NaN  600.0  2000000000024        48        NaN
# 6   2000  200004       3       NaN  600.0  2000000000034        13        NaN
# 7   2000  200004       4       NaN  600.0  2000000000044        12        NaN
# 8   2000  200004       5       NaN  600.0  2000000000054        12        NaN
# 9   2000  200004       5       NaN  600.0  2000000000054        12        NaN
# 10  2000  200004       5       NaN  600.0  2000000000054        12        NaN
# ...

# %%
df.dtypes
# Out:
# YEAR           int64
# SAMPLE         int64
# SERIAL         int64
# CBSERIAL     float64
# HHWT         float64
# CLUSTER        int64
# STATEFIP       int64
# COUNTYFIP    float64
# DENSITY      float64
# METRO        float64
# METAREA      float64
# METAREAD     float64
# STRATA         int64
# GQ             int64
# PERNUM         int64
# PERWT        float64
# RACE           int64
# RACED          int64
# HISPAN         int64
# HISPAND        int64
# CITIZEN        int64
# HCOVANY      float64
# HCOVPRIV     float64
# HCOVPUB      float64
# HINSCAID     float64
# HINSCARE     float64
# SCHOOL         int64
# EDUC           int64
# EDUCD          int64
# EMPSTAT        int64
# EMPSTATD       int64
# LABFORCE       int64
# CLASSWKR       int64
# CLASSWKRD      int64
# OCC            int64
# IND            int64
# INCTOT         int64
# INCWAGE        int64
# DISABWRK       int64
# VETSTAT        int64
# VETSTATD       int64
# VETYRS         int64
# dtype: object
