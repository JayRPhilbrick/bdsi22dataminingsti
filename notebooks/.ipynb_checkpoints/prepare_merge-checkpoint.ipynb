# %%
import numpy as np
import pandas as pd
import os

# %%
df1 = pd.read_csv('../Data/Clean/COVIDcounts_county_clean.csv', index_col = 0)
print(df1.shape)
df1.head()
# Out:
# (3142, 895)
#    fips      county_name state  statefips  2020-01-22  2020-01-23  2020-01-24  \
# 1  1001  Autauga County     AL          1           0           0           0
# 2  1003  Baldwin County     AL          1           0           0           0
# 3  1005  Barbour County     AL          1           0           0           0
# 4  1007     Bibb County     AL          1           0           0           0
# 5  1009   Blount County     AL          1           0           0           0
#
#    2020-01-25  2020-01-26  2020-01-27  ...  2022-06-21  2022-06-22  \
# 1           0           0           0  ...       16313       16330
# 2           0           0           0  ...       58009       58169
# 3           0           0           0  ...        5813        5818
# 4           0           0           0  ...        6630        6648
# 5           0           0           0  ...       15246       15249
#
#    2022-06-23  2022-06-24  2022-06-25  2022-06-26  2022-06-27  2022-06-28  \
# 1       16360       16400       16400       16400       16468       16496
# 2       58293       58372       58372       58372       58595       58695
# 3        5825        5832        5832        5832        5857        5863
# 4        6654        6663        6663        6663        6679        6687
# 5       15272       15283       15283       15283       15324       15335
#
#    2022-06-29  2022-06-30
# 1       16520       16536
# 2       58796       58905
# 3        5880        5891
# 4        6700        6704
# 5       15351       15370
#
# [5 rows x 895 columns]

# %%
for index, column in enumerate(df1.columns[:]):
    if column.startswith('2020-12-30'):
        labs20 = column
    if column.startswith('2021-12-30'):
        labs21 = column
    if column.startswith('2022-06-30'):
        labs22 = column

print(labs20)
print(labs21)
print(labs22)
# Out:
# 2020-12-30
# 2021-12-30
# 2022-06-30

# %%
df1 = pd.DataFrame(np.repeat(df1.values, 3, axis = 0), columns = df1.columns)
df1.head()
# Out:
#    fips      county_name state statefips 2020-01-22 2020-01-23 2020-01-24  \
# 0  1001  Autauga County     AL         1          0          0          0
# 1  1001  Autauga County     AL         1          0          0          0
# 2  1001  Autauga County     AL         1          0          0          0
# 3  1003  Baldwin County     AL         1          0          0          0
# 4  1003  Baldwin County     AL         1          0          0          0
#
#   2020-01-25 2020-01-26 2020-01-27  ... 2022-06-21 2022-06-22 2022-06-23  \
# 0          0          0          0  ...      16313      16330      16360
# 1          0          0          0  ...      16313      16330      16360
# 2          0          0          0  ...      16313      16330      16360
# 3          0          0          0  ...      58009      58169      58293
# 4          0          0          0  ...      58009      58169      58293
#
#   2022-06-24 2022-06-25 2022-06-26 2022-06-27 2022-06-28 2022-06-29 2022-06-30
# 0      16400      16400      16400      16468      16496      16520      16536
# 1      16400      16400      16400      16468      16496      16520      16536
# 2      16400      16400      16400      16468      16496      16520      16536
# 3      58372      58372      58372      58595      58695      58796      58905
# 4      58372      58372      58372      58595      58695      58796      58905
#
# [5 rows x 895 columns]

# %%
df1['year'] = None
for index in df1.index:
    if index % 3 == 0:
        df1.iloc[index, -1] = 2020
    elif index % 3 == 1:
        df1.iloc[index, -1] = 2021
    else:
        df1.iloc[index, -1] = 2022
df1.head()
# Out:
#    fips      county_name state statefips 2020-01-22 2020-01-23 2020-01-24  \
# 0  1001  Autauga County     AL         1          0          0          0
# 1  1001  Autauga County     AL         1          0          0          0
# 2  1001  Autauga County     AL         1          0          0          0
# 3  1003  Baldwin County     AL         1          0          0          0
# 4  1003  Baldwin County     AL         1          0          0          0
#
#   2020-01-25 2020-01-26 2020-01-27  ... 2022-06-22 2022-06-23 2022-06-24  \
# 0          0          0          0  ...      16330      16360      16400
# 1          0          0          0  ...      16330      16360      16400
# 2          0          0          0  ...      16330      16360      16400
# 3          0          0          0  ...      58169      58293      58372
# 4          0          0          0  ...      58169      58293      58372
#
#   2022-06-25 2022-06-26 2022-06-27 2022-06-28 2022-06-29 2022-06-30  year
# 0      16400      16400      16468      16496      16520      16536  2020
# 1      16400      16400      16468      16496      16520      16536  2021
# 2      16400      16400      16468      16496      16520      16536  2022
# 3      58372      58372      58595      58695      58796      58905  2020
# 4      58372      58372      58595      58695      58796      58905  2021
#
# [5 rows x 896 columns]

# %%
df1['covid_cases'] = None
df1.head()
# Out:
#    fips      county_name state statefips 2020-01-22 2020-01-23 2020-01-24  \
# 0  1001  Autauga County     AL         1          0          0          0
# 1  1001  Autauga County     AL         1          0          0          0
# 2  1001  Autauga County     AL         1          0          0          0
# 3  1003  Baldwin County     AL         1          0          0          0
# 4  1003  Baldwin County     AL         1          0          0          0
#
#   2020-01-25 2020-01-26 2020-01-27  ... 2022-06-23 2022-06-24 2022-06-25  \
# 0          0          0          0  ...      16360      16400      16400
# 1          0          0          0  ...      16360      16400      16400
# 2          0          0          0  ...      16360      16400      16400
# 3          0          0          0  ...      58293      58372      58372
# 4          0          0          0  ...      58293      58372      58372
#
#   2022-06-26 2022-06-27 2022-06-28 2022-06-29 2022-06-30  year covid_cases
# 0      16400      16468      16496      16520      16536  2020        None
# 1      16400      16468      16496      16520      16536  2021        None
# 2      16400      16468      16496      16520      16536  2022        None
# 3      58372      58595      58695      58796      58905  2020        None
# 4      58372      58595      58695      58796      58905  2021        None
#
# [5 rows x 897 columns]

# %%
for index in df1.index:
    if index % 3 == 0:
        df1.iloc[index,-1] = df1.loc[index,labs20]
    elif index % 3 == 1:
        df1.iloc[index,-1] = df1.loc[index,labs21]
    else:
        df1.iloc[index,-1] = df1.loc[index,labs22]
df1
# Out:
#        fips       county_name state statefips 2020-01-22 2020-01-23  \
# 0      1001   Autauga County     AL         1          0          0
# 1      1001   Autauga County     AL         1          0          0
# 2      1001   Autauga County     AL         1          0          0
# 3      1003   Baldwin County     AL         1          0          0
# 4      1003   Baldwin County     AL         1          0          0
# ...     ...               ...   ...       ...        ...        ...
# 9421  56043  Washakie County     WY        56          0          0
# 9422  56043  Washakie County     WY        56          0          0
# 9423  56045    Weston County     WY        56          0          0
# 9424  56045    Weston County     WY        56          0          0
# 9425  56045    Weston County     WY        56          0          0
#
#      2020-01-24 2020-01-25 2020-01-26 2020-01-27  ... 2022-06-23 2022-06-24  \
# 0             0          0          0          0  ...      16360      16400
# 1             0          0          0          0  ...      16360      16400
# 2             0          0          0          0  ...      16360      16400
# 3             0          0          0          0  ...      58293      58372
# 4             0          0          0          0  ...      58293      58372
# ...         ...        ...        ...        ...  ...        ...        ...
# 9421          0          0          0          0  ...       2490       2490
# 9422          0          0          0          0  ...       2490       2490
# 9423          0          0          0          0  ...       1641       1641
# 9424          0          0          0          0  ...       1641       1641
# 9425          0          0          0          0  ...       1641       1641
#
#      2022-06-25 2022-06-26 2022-06-27 2022-06-28 2022-06-29 2022-06-30  year  \
# 0         16400      16400      16468      16496      16520      16536  2020
# 1         16400      16400      16468      16496      16520      16536  2021
# 2         16400      16400      16468      16496      16520      16536  2022
# 3         58372      58372      58595      58695      58796      58905  2020
# 4         58372      58372      58595      58695      58796      58905  2021
# ...         ...        ...        ...        ...        ...        ...   ...
# 9421       2490       2490       2490       2482       2482       2482  2021
# 9422       2490       2490       2490       2482       2482       2482  2022
# 9423       1641       1641       1641       1643       1643       1643  2020
# 9424       1641       1641       1641       1643       1643       1643  2021
# 9425       1641       1641       1641       1643       1643       1643  2022
#
#      covid_cases
# 0           4164
# 1          10953
# 2          16536
# 3          13392
# 4          39583
# ...          ...
# 9421        1880
# 9422        2482
# 9423         475
# 9424        1254
# 9425        1643
#
# [9426 rows x 897 columns]

# %%
df = df1[['year', 'fips','covid_cases', 'county_name']]
print(df.dtypes)
df[['year','fips','covid_cases']] = df[['year','fips','covid_cases']].apply(pd.to_numeric)
print(df.dtypes)
df
# Out:
# year           object
# fips           object
# covid_cases    object
# county_name    object
# dtype: object
# year            int64
# fips            int64
# covid_cases     int64
# county_name    object
# dtype: object
# C:\Users\FPSKINSMANC\Anaconda3\lib\site-packages\pandas\core\frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       year   fips  covid_cases       county_name
# 0     2020   1001         4164   Autauga County
# 1     2021   1001        10953   Autauga County
# 2     2022   1001        16536   Autauga County
# 3     2020   1003        13392   Baldwin County
# 4     2021   1003        39583   Baldwin County
# ...    ...    ...          ...               ...
# 9421  2021  56043         1880  Washakie County
# 9422  2022  56043         2482  Washakie County
# 9423  2020  56045          475    Weston County
# 9424  2021  56045         1254    Weston County
# 9425  2022  56045         1643    Weston County
#
# [9426 rows x 4 columns]

# %%
df.to_csv('../Data/Intermediate/COVIDcounty_cases_processed.csv', index = False)

# %%
dp03, dp05 = [], []
path = '../Data/Clean/ACS'
for file in os.listdir(path):
    if file.find('DP03') != -1:
        #print(file)
        dp03.append(pd.read_csv(os.path.join(path, file), index_col = 0))
    if file.find('DP05') != -1:
        dp05.append(pd.read_csv(os.path.join(path, file), index_col = 0))

i = 0
while i != 5:
    dp03[i].drop(columns = ['geographic_area_name','id'], inplace = True)
    print('03: ', dp03[i].shape)
    dp05[i].drop(columns = ['Geographic Area Name','id'], inplace = True)
    print('05: ',dp05[i].shape)
    i += 1
# Out:
# 03:  (3220, 20)
# 05:  (3220, 33)
# 03:  (3220, 20)
# 05:  (3220, 34)
# 03:  (3220, 20)
# 05:  (3220, 34)
# 03:  (3220, 20)
# 05:  (3220, 34)
# 03:  (3221, 20)
# 05:  (3221, 34)

# %%
type(dp03[0])
# Out:
# pandas.core.frame.DataFrame

# %%
i = 2
tot_dp03 = pd.concat([dp03[0], dp03[1]], ignore_index = True)
tot_dp05 = pd.concat([dp05[0], dp05[1]], ignore_index = True)

while i != 5:
    tot_dp03 = pd.concat([tot_dp03, dp03[i]], ignore_index = True)
    tot_dp05 = pd.concat([tot_dp05, dp05[i]], ignore_index = True)
    i += 1

print(tot_dp03.shape)
print(tot_dp05.shape)
# Out:
# (16101, 24)
# (16101, 34)

# %%
tot_dp03.to_csv('../Data/Intermediate/ACSDP03_merge.csv')
tot_dp05.to_csv('../Data/Intermediate/ACSDP05_merge.csv')
