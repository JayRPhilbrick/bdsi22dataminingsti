# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_pop = pd.read_csv("../Data/Intermediate/ACSDP05_merge.csv")
# Out:
# /var/folders/m9/xn_kvh7s6191dgzxbr9l38x00000gn/T/ipykernel_68545/2360043603.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_pop = pd.read_csv("../Data/Intermediate/ACSDP05_merge.csv")

# %%
data_covid = pd.read_csv("../Data/Clean/USAFacts/COVIDcounts_county_clean_2.csv")

# %%
data_pop.head()
# Out:
#    Unnamed: 0  pct_sex_age_male  pct_sex_age_female  pct_sex_age_85+  \
# 0           0              48.5                51.5              1.1
# 1           1              48.9                51.1              1.6
# 2           2              52.9                47.1              1.8
# 3           3              53.8                46.2              0.7
# 4           4              49.5                50.5              1.2
#
#   median_age  pct_sex_age_18+  pct_sex_age_21+  pct_sex_age_62+  \
# 0       36.2             72.3             67.9             14.3
# 1       41.0             76.7             73.3             20.1
# 2       38.0             77.5             73.7             16.7
# 3       38.3             76.6             72.5             15.7
# 4       38.3             75.2             71.3             18.1
#
#    pct_sex_age_65+  pct_one_or_more_race  ...  pct_sex_age_18+_female  \
# 0             11.4                 53155  ...                     NaN
# ...

# %%
data_covid.head()
# Out:
#    Unnamed: 0  fips      county_name state  statefips  1/22/20  1/23/20  \
# 0           1  1001  Autauga County     AL          1        0        0
# 1           2  1003  Baldwin County     AL          1        0        0
# 2           3  1005  Barbour County     AL          1        0        0
# 3           4  1007     Bibb County     AL          1        0        0
# 4           5  1009   Blount County     AL          1        0        0
#
#    1/24/20  1/25/20  1/26/20  ...  6/22/22  6/23/22  6/24/22  6/25/22  \
# 0        0        0        0  ...    16330    16360    16400    16400
# 1        0        0        0  ...    58169    58293    58372    58372
# 2        0        0        0  ...     5818     5825     5832     5832
# 3        0        0        0  ...     6648     6654     6663     6663
# 4        0        0        0  ...    15249    15272    15283    15283
#
#    6/26/22  6/27/22  6/28/22  6/29/22  6/30/22  sum of 2020
# ...

# %%
plt.figure(figsize = (15,8))
g = sns.scatterplot(x = df_ref['rate per 100000'][2019],y = df_ref['rate per 100000'][2020],size = df_ref.total_pop[2019],sizes=(10, 1000),alpha=0.5)
xpoints = ypoints = plt.xlim()
plt.plot(xpoints, ypoints, linestyle='--', color='k', lw=3, scalex=False, scaley=False)
# sns.lineplot(x = [1,2],y =[1,2])
plt.title("Chlamydia")
plt.savefig("../Output/EDA/Chlamydia_scatterplot.png",dpi = 300)
# plt.axhline(y=0,c="black")
plt.show()
