# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("..\Data\Raw\ACS\ACSDP052018.csv", skiprows=1)
df["year"] = 2018
df.head(5)
# Out:
#   Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female  \
# 0                                                0.4
# 1                                                0.1
# 2                                                0.2
# 3                                                1.3
# 4                                                0.5
#
#   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#   Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                1.2
# 1                                                0.3
# ...

# %%
list(df.columns)
# Out:
# ['Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Margin of Error!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Percent Margin of Error!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Margin of Error!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Percent Margin of Error!!RACE!!Total population!!One race',
#  'Estimate!!RACE!!Total population!!Two or more races',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='Margin of Error')))]
df.head(5)
# Out:
#   Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#   Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Estimate!!RACE!!Total population  Percent Estimate!!RACE!!Total population  \
# 0                             55200                                     55200
# ...

# %%
list(df.columns)
# Out:
# ['Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)',
#  'Estimate!!RACE!!Total population',
#  'Percent Estimate!!RACE!!Total population',
#  'Estimate!!RACE!!Total population!!One race',
#  'Percent Estimate!!RACE!!Total population!!One race',
#  'Estimate!!RACE!!Total population!!Two or more races',
#  'Percent Estimate!!RACE!!Total population!!Two or more races',
#  'Estimate!!RACE!!Total population!!One race.1',
#  'Percent Estimate!!RACE!!Total population!!One race.1',
#  'Estimate!!RACE!!Total population!!One race!!White',
#  'Percent Estimate!!RACE!!Total population!!One race!!White',
#  'Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Percent Estimate!!RACE!!Total population!!One race!!Black or African American',
#  'Estimate!!RACE!!Total population!!One race!!American Indian and Alaska Native',
# ...

# %%
df = df.rename(columns = {'Estimate!!SEX AND AGE!!Median age (years)' : 'median_age'})

# %%
total_pop_col = df[["Estimate!!SEX AND AGE!!Total population", "id"]]
df = df[df.columns.drop(list(df.filter(regex='^Estimate')))]
df = df[df.columns.drop(list(df.filter(regex='Percent!!SEX AND AGE!!Total population')))]
df = df[df.columns.drop(list(df.filter(regex='RACE!!Two or more races!!')))]
df = df[df.columns.drop(list(df.filter(regex='RACE!!One race!!')))]
df = pd.merge(df, total_pop_col, how="left", on="id")
df.head(5)
# Out:
#   Percent Estimate!!SEX AND AGE!!Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    Percent Estimate!!RACE!!Total population  \
# 0                                     55200
# 1                                    208107
# 2                                     25782
# 3                                     22527
# 4                                     57645
#
#    Percent Estimate!!RACE!!Total population!!One race  \
# 0                                               98.1
# 1                                               98.3
# 2                                               98.6
# 3                                               99.2
# ...

# %%
df.columns = df.columns.str.replace('Estimate!!SEX AND AGE!!Total population_y', 'total_pop')
df.columns = df.columns.str.replace('Percent Estimate!!', 'pct_')
df.columns = df.columns.str.replace('SEX AND AGE!!', 'sex_age_')
df.columns = df.columns.str.replace('HISPANIC OR LATINO AND RACE!!', 'ethnicity_')
df.columns = df.columns.str.replace('RACE!!', 'race_')
df.columns = df.columns.str.replace('Male', 'male')
df.columns = df.columns.str.replace('Female', 'female')
df.columns = df.columns.str.replace('CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!', 'voting_age_citizen_')
df.columns = df.columns.str.replace('Race alone or in combination with one or more other races', 'one_or_more_race')
df.head(5)
# Out:
#   pct_sex_age_Total population!!65 years and over!!Sex ratio (males per 100 females)  \
# 0                                                (X)
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#    pct_race_Total population  pct_race_Total population!!One race  \
# 0                      55200                                 98.1
# 1                     208107                                 98.3
# 2                      25782                                 98.6
# 3                      22527                                 99.2
# 4                      57645                                 98.4
#
#    pct_race_Total population!!Two or more races  \
# 0                                           1.9
# 1                                           1.7
# 2                                           1.4
# ...

# %%
# df = df.drop(columns=["pct_sex_age_Median age (years)"])
df.columns = df.columns.str.replace('Under 5 years', 'under_5')
df.columns = df.columns.str.replace('5 to 9 years', '5_to_9')
df.columns = df.columns.str.replace('10 to 14 years', '10_to_14')
df.columns = df.columns.str.replace('15 to 19 years', '15_to_19')
df.columns = df.columns.str.replace('20 to 24 years', '20_to_24')
df.columns = df.columns.str.replace('25 to 34 years', '25_to_34')
df.columns = df.columns.str.replace('35 to 44 years', '35_to_44')
df.columns = df.columns.str.replace('45 to 54 years', '45_to_54')
df.columns = df.columns.str.replace('55 to 59 years', '55_to_59')
df.columns = df.columns.str.replace('60 to 64 years', '60_to_64')
df.columns = df.columns.str.replace('65 to 74 years', '65_to_74')
df.columns = df.columns.str.replace('75 to 84 years', '75_to_84')
df.columns = df.columns.str.replace(' years and over', '+')
df.columns = df.columns.str.replace('!!male', '_male')
df.columns = df.columns.str.replace('!!female', '_female')


list(df.columns)
# Out:
# ['pct_sex_age_Total population!!65+!!Sex ratio (males per 100 females)',
#  'pct_race_Total population',
#  'pct_race_Total population!!One race',
#  'pct_race_Total population!!Two or more races',
#  'pct_race_Total population!!One race.1',
#  'pct_race_Total population!!One race!!White',
#  'pct_race_Total population!!One race!!Black or African American',
#  'pct_race_Total population!!One race!!American Indian and Alaska Native',
#  'pct_race_Total population!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping',
#  'pct_race_Total population!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping',
#  'pct_race_Total population!!One race!!American Indian and Alaska Native!!Navajo tribal grouping',
#  'pct_race_Total population!!One race!!American Indian and Alaska Native!!Sioux tribal grouping',
#  'pct_race_Total population!!One race!!Asian',
#  'pct_race_Total population!!One race!!Asian!!Asian Indian',
# ...

# %%
# df = df.drop(columns = ["pct_sex_age_65+.1"])
# df = df.drop(columns = ["pct_sex_age_18+.1"])
# df = df.drop(columns=["pct_race_Total population!!One race"])
# df = df.drop(columns=["pct_race_Total population!!Two or more races"])
# df = df.drop(columns=["pct_race_One race"])
# df = df.drop(columns=["pct_race_Total population"])
# df = df.drop(columns=["pct_race_Two or more races"])
# df = df.drop(columns=["pct_ethnicity_Total population"])
df.columns = df.columns.str.replace('!!Total population', '')
df.columns = df.columns.str.replace('!!Total population', '')
df.columns = df.columns.str.replace('Total population', '')
df.columns = df.columns.str.replace('!!Hispanic or Latino (of any race)!!', 'hispanic_')
df.columns = df.columns.str.replace('!!Not Hispanic or Latino!!', 'not_hispanic_')


list(df.columns)
# Out:
# C:\Users\philb\AppData\Local\Temp\ipykernel_22344\3328666660.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('!!Hispanic or Latino (of any race)!!', 'hispanic_')
# ['pct_sex_age_!!65+!!Sex ratio (males per 100 females)',
#  'pct_race_',
#  'pct_race_!!One race',
#  'pct_race_!!Two or more races',
#  'pct_race_!!One race.1',
#  'pct_race_!!One race!!White',
#  'pct_race_!!One race!!Black or African American',
#  'pct_race_!!One race!!American Indian and Alaska Native',
#  'pct_race_!!One race!!American Indian and Alaska Native!!Cherokee tribal grouping',
#  'pct_race_!!One race!!American Indian and Alaska Native!!Chippewa tribal grouping',
#  'pct_race_!!One race!!American Indian and Alaska Native!!Navajo tribal grouping',
#  'pct_race_!!One race!!American Indian and Alaska Native!!Sioux tribal grouping',
#  'pct_race_!!One race!!Asian',
#  'pct_race_!!One race!!Asian!!Asian Indian',
# ...

# %%
df = df[df.columns.drop(list(df.filter(regex='^pct_ethnicity_not_hispanic')))]
df = df[df.columns.drop(list(df.filter(regex='^pct_ethnicity_!!Hispanic or Latino (of any race)!!')))]
df = df[df.columns.drop(list(df.filter(regex='^pct_voting_age')))]

df = df.drop(columns=["pct_ethnicity_!!Hispanic or Latino (of any race)!!Mexican"])
df = df.drop(columns=["pct_ethnicity_!!Hispanic or Latino (of any race)!!Puerto Rican"])
df = df.drop(columns=["pct_ethnicity_!!Hispanic or Latino (of any race)!!Cuban"])
df = df.drop(columns=["pct_ethnicity_!!Hispanic or Latino (of any race)!!Other Hispanic or Latino"])
df = df.drop(columns=["pct_ethnicity_!!Not Hispanic or Latino"])
df = df.drop(columns=["pct_Total housing units"])
df = df.drop(columns=["pct_CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population"])

df.columns = df.columns.str.replace('White', 'white')
df.columns = df.columns.str.replace('Black or African American', 'black')

df.columns = df.columns.str.replace('American Indian and Alaska Native', 'native_american')
df.columns = df.columns.str.replace('Asian', 'asian')
df.columns = df.columns.str.replace('Native Hawaiian and Other Pacific Islander', 'native_hawaiian_pacific_islander')
df.columns = df.columns.str.replace('Some other race', 'other_race')
df = df.rename(columns = {"pct_ethnicity_!!Hispanic or Latino (of any race)":"pct_ethnicity_hispanic"})
df.columns = df.columns.str.replace('!!', '_')
df.columns = df.columns.str.replace('pct_race', 'pct')
df.columns = df.columns.str.replace('__', '_')

df = df.drop(columns = ["pct_"])
df = df[df.columns.drop(list(df.filter(regex='^pct_One')))]
df = df[df.columns.drop(list(df.filter(regex='^pct_Two')))]

df = df.rename(columns = {"Estimate_sex_age_":"total_pop"})
df = df.drop(columns=["pct_ethnicity_", "pct_sex_age_65+_Sex ratio (males per 100 females)", "pct_sex_age_Sex ratio (males per 100 females)", "pct_sex_age_18+_Sex ratio (males per 100 females)", "pct_sex_age_", "pct_sex_age_male", "pct_sex_age_female", "pct_sex_age_Under 18 years"])
df = df[df.columns.drop(list(df.filter(regex='.1$')))]


df = df.rename(columns = {"pct_sex_age_Median age (years)":"median_age"})

list(df.columns)
# Out:
# ['pct_one_or_more_race',
#  'pct_one_or_more_race_white',
#  'pct_one_or_more_race_black',
#  'pct_one_or_more_race_native_american',
#  'pct_one_or_more_race_asian',
#  'pct_one_or_more_race_native_hawaiian_pacific_islander',
#  'pct_one_or_more_race_other_race',
#  'pct_ethnicity_hispanic',
#  'id',
#  'pct_sex_age_under_5',
#  'pct_sex_age_5_to_9',
#  'pct_sex_age_10_to_14',
#  'pct_sex_age_15_to_19',
#  'pct_sex_age_20_to_24',
#  'pct_sex_age_25_to_34',
#  'pct_sex_age_35_to_44',
#  'pct_sex_age_45_to_54',
#  'pct_sex_age_55_to_59',
#  'pct_sex_age_60_to_64',
#  'pct_sex_age_65_to_74',
#  'pct_sex_age_75_to_84',
#  'pct_sex_age_85+',
#  'median_age',
#  'pct_sex_age_16+',
#  'pct_sex_age_18+',
#  'pct_sex_age_21+',
#  'pct_sex_age_62+',
#  'pct_sex_age_65+',
#  'pct_sex_age_18+_male',
#  'pct_sex_age_18+_female',
#  'pct_sex_age_65+_male',
#  'pct_sex_age_65+_female',
#  'Geographic Area Name',
#  'year',
#  'total_pop']

# %%
df.head()
# Out:
#    pct_one_or_more_race  pct_one_or_more_race_white  \
# 0                 55200                        78.6
# 1                208107                        87.8
# 2                 25782                        48.3
# 3                 22527                        77.4
# 4                 57645                        97.1
#
#    pct_one_or_more_race_black  pct_one_or_more_race_native_american  \
# 0                        19.9                                   0.8
# 1                         9.8                                   1.5
# 2                        48.5                                   1.2
# 3                        22.7                                   0.4
# 4                         1.9                                   1.2
#
#    pct_one_or_more_race_asian  \
# 0                         1.6
# 1                         1.4
# 2                         0.6
# 3                         0.2
# 4                         0.5
#
# ...

# %%
# temp_cols = df['Geographic Area Name'].str.split(',', n=1, expand=True)
# temp_cols = temp_cols.rename(columns = {"0" : "county", "1" : "state"})
# temp_cols.head(5)

# temp_cols = temp_cols["0"].str.replace('County', '')

df.to_csv("ACSDP052018_clean.csv")

# FOR SOME REASON, THIS FILEPATH IS NOT WORKING!!
# df.to_csv("..\Data\Clean\ACS\ACSDP052016_clean.csv")
